# %%
import rltk
import csv
from datetime import datetime
tokenizer = rltk.tokenizer.crf_tokenizer.crf_tokenizer.CrfTokenizer()

# %%
class gCompanyRecord(rltk.Record):
    def __init__(self, raw_object):
        super().__init__(raw_object)
        self.name = ''

    @rltk.cached_property
    def id(self):
        return self.raw_object['ID']
    
    # attribute 1: company name
    @rltk.cached_property
    def name_string(self):
        return self.raw_object['name'].lower()
    
    # attribute 2: headquarter
    @rltk.cached_property
    def headquarter_string(self):
        return self.raw_object['city']
    
    # attribute 3: company size
    @rltk.cached_property
    def size_string(self):
        return self.raw_object['size']
    
    # attribute 4：website
    @rltk.cached_property
    def website_string(self):
        website = self.raw_object['company_url']
        if website != "":
            if website[-1] != "/":
                website += "/" 
        return website
    
    # attribute 5: first three characters in company name
    @rltk.cached_property
    def first3title(self):
        chars = self.name_string[:3]
        return chars
    
    # attribute 6: website removed http
    @rltk.cached_property
    def website_nohttp(self):
        website = self.website_string
        website = website.replace("http://", "").replace("https://", "")
        return website
    
    
class lCompanyRecord(rltk.Record):
    def __init__(self, raw_object):
        super().__init__(raw_object)
        self.name = ''

    @rltk.cached_property
    def id(self):
        return self.raw_object['ID']
    
    # attribute 1: company name
    @rltk.cached_property
    def name_string(self):
        return self.raw_object['company_name'].lower()
    
    # attribute 2: headquarter
    @rltk.cached_property
    def headquarter_string(self):
        return self.raw_object['city']
    
    # attribute 3: company size
    @rltk.cached_property
    def size_string(self):
        return self.raw_object['size']
    
    # attribute 4：website
    @rltk.cached_property
    def website_string(self):
        website = self.raw_object['website']
        if website != "":
            if website[-1] != "/":
                website += "/" 
        return website
    
    # attribute 5: first three characters in company name
    @rltk.cached_property
    def first3title(self):
        chars = self.name_string[:3]
        return chars
    
    # attribute 6: website removed http
    @rltk.cached_property
    def website_nohttp(self):
        website = self.website_string
        website = website.replace("http://", "").replace("https://", "")
        return website

class wCompanyRecord(rltk.Record):
    def __init__(self, raw_object):
        super().__init__(raw_object)
        self.name = ''

    @rltk.cached_property
    def id(self):
        return self.raw_object['item']
    # attribute 1: company name
    @rltk.cached_property
    def name_string(self):
        return self.raw_object['itemLabel'].lower()
    
    # attribute 2: headquarter
    @rltk.cached_property
    def headquarter_string(self):
        return self.raw_object['locationLabel']
    
    # attribute 4：website
    @rltk.cached_property
    def website_string(self):
        website = self.raw_object['website']
        if website != "":
            if website[-1] != "/":
                website += "/" 
        return website
    
    # attribute 5: first three characters in company name
    @rltk.cached_property
    def first3title(self):
        chars = self.name_string[:3]
        return chars
    
    # attribute 6: website removed http
    @rltk.cached_property
    def website_nohttp(self):
        website = self.website_string
        website = website.replace("http://", "").replace("https://", "")
        return website

# %%
dir_ = '../csvfile_category/'
gc_file = dir_ + 'glassdoor_company_withid.csv'
lc_file = dir_ + 'linkedin_company_withid.csv'
wc_file = dir_ + 'wikidata_company.csv'

ds_linkedin = rltk.Dataset(rltk.CSVReader(lc_file),record_class=lCompanyRecord)
ds_glassdoor = rltk.Dataset(rltk.CSVReader(gc_file),record_class=gCompanyRecord)
ds_wikidata = rltk.Dataset(rltk.CSVReader(wc_file),record_class=wCompanyRecord)

# %% [markdown]
# ### blocking linkedin-glassdoor

# %%
bg = rltk.HashBlockGenerator()

block = bg.generate(
    bg.block(ds_glassdoor, property_="first3title"),
    bg.block(ds_linkedin, property_="first3title")
)

# %% [markdown]
# ### entity linking

# %%
def title_string_similarity(s1, s2):
    return rltk.jaro_winkler_similarity(s1, s2)
    
def name_string_similarity(s1, s2):
    return 1-rltk.levenshtein_distance(s1, s2)

def website_similarity(s1, s2):
    if s1 == s2:
        return 1
    if s1 == "" or s2 == "":
        return 0.5
    return 0

# %%
# threshold value to determine if we are confident the record match
MY_TRESH = 0.7

# entity linkage scoring function
def rule_based_method(r1, r2):
    score_1 = name_string_similarity(r1.name_string, r2.name_string)
    score_2 = website_similarity(r1.website_string, r2.website_string)
    
    total = 0.7 * score_1 + 0.3 * score_2
    
    # return two values: boolean if they match or not, float to determine confidence
    return total > MY_TRESH, total

# %%
matchPairs = []
for r_glassdoor, r_linkedin in rltk.get_record_pairs(ds_glassdoor, ds_linkedin, block=block):
    result, confidence = rule_based_method(r_glassdoor, r_linkedin)
    if result == True:
        matchPairs.append([r_glassdoor.id, r_linkedin.id, confidence])

# %%
len(matchPairs)
# Out:
# 64

# %%
for ids in matchPairs:
    print(ids)
    r_glassdoor = ds_glassdoor.get_record(ids[0])
    r_linkedin = ds_linkedin.get_record(ids[1])
    print(r_glassdoor.name_string, r_glassdoor.website_string)
    print(r_linkedin.name_string, r_linkedin.website_string, "\n")
# Out:
# ['5', '2434', 1.0]
# the home depot http://www.careers.homedepot.com/
# the home depot http://www.careers.homedepot.com/
#
# ['6', '2633', 1.0]
# usaa http://www.usaajobs.com/
# usaa http://www.usaajobs.com/
#
# ['18', '1168', 1.0]
# bp http://www.bp.com/
# bp http://www.bp.com/
#
# ['592', '1756', 1.0]
# citi http://www.citigroup.com/
# citi http://www.citigroup.com/
#
# ['739', '1944', 1.0]
# capstoneone search http://www.capstoneonesearch.com/
# capstoneone search http://www.capstoneonesearch.com/
#
# ['765', '2229', 1.0]
# expedition technology inc http://www.exptechinc.com/
# expedition technology inc http://www.exptechinc.com/
#
# ['25', '2314', 1.0]
# liberty mutual insurance http://www.libertymutualgroup.com/
# liberty mutual insurance http://www.libertymutualgroup.com/
#
# ['29', '1926', 1.0]
# ursus, inc. http://www.ursusinc.com/
# ursus, inc. http://www.ursusinc.com/
#
# ['30', '69', 1.0]
# harnham http://www.harnham.com/
# harnham http://www.harnham.com/
#
# ['31', '2501', 1.0]
# apex systems http://www.apexsystems.com/
# apex systems http://www.apexsystems.com/
#
# ['35', '2086', 1.0]
# matlen silver http://www.matlensilver.com/
# matlen silver http://www.matlensilver.com/
#
# ['143', '2134', 0.85]
# confidential http://www.escalon.services/
# confidential
#
# ['117', '2134', 0.85]
# confidential http://www.polarisrx.com/
# confidential
#
# ['52', '1858', 1.0]
# analog devices http://www.analog.com/
# analog devices http://www.analog.com/
#
# ['324', '703', 1.0]
# paciolan http://www.paciolan.com/
# paciolan http://www.paciolan.com/
#
# ['60', '2388', 1.0]
# peraton http://www.peraton.com/
# peraton http://www.peraton.com/
#
# ['146', '1769', 1.0]
# disys http://www.disys.com/
# disys http://www.disys.com/
#
# ['90', '2396', 1.0]
# air products http://www.airproducts.com/
# air products http://www.airproducts.com/
#
# ['95', '1107', 1.0]
# cybercoders http://www.cybercoders.com/
# cybercoders http://www.cybercoders.com/
#
# ['102', '1673', 1.0]
# navy federal credit union http://www.navyfederal.org/
# navy federal credit union http://www.navyfederal.org/
#
# ['921', '1022', 1.0]
# dick's sporting goods http://www.dickssportinggoods.jobs/
# dick's sporting goods http://www.dickssportinggoods.jobs/
#
# ['392', '1560', 1.0]
# spacex http://www.spacex.com/
# spacex http://www.spacex.com/
#
# ['152', '179', 1.0]
# boutique recruiting http://www.boutiquerecruiting.com/
# boutique recruiting http://www.boutiquerecruiting.com/
#
# ['155', '2182', 1.0]
# gpac http://www.gogpac.com/
# gpac http://www.gogpac.com/
#
# ['160', '2427', 1.0]
# cbre http://www.cbre.com/
# cbre http://www.cbre.com/
#
# ['198', '2343', 1.0]
# us foods http://www.usfoods.com/
# us foods http://www.usfoods.com/
#
# ['175', '1696', 1.0]
# cps energy http://www.cpsenergy.com/
# cps energy http://www.cpsenergy.com/
#
# ['936', '2680', 0.85]
# act! llc http://www.act.com/
# act! llc
#
# ['202', '1235', 1.0]
# halff associates http://www.halff.com/
# halff associates http://www.halff.com/
#
# ['203', '1352', 1.0]
# ifg companies http://www.ifgcompanies.com/
# ifg companies http://www.ifgcompanies.com/
#
# ['901', '1065', 1.0]
# american red cross http://www.redcross.org/
# american red cross http://www.redcross.org/
#
# ['218', '373', 1.0]
# larson maddox https://www.larsonmaddox.com/
# larson maddox https://www.larsonmaddox.com/
#
# ['221', '384', 1.0]
# cepheid http://www.cepheid.com/
# cepheid http://www.cepheid.com/
#
# ['270', '1432', 1.0]
# aquent http://www.aquent.com/
# aquent http://www.aquent.com/
#
# ['310', '705', 1.0]
# onward search https://www.onwardsearch.com/
# onward search https://www.onwardsearch.com/
#
# ['330', '1126', 1.0]
# aecom http://www.aecom.com/
# aecom http://www.aecom.com/
#
# ['341', '2271', 1.0]
# rti international http://www.rti.org/
# rti international http://www.rti.org/
#
# ['360', '1656', 1.0]
# gridiron it http://www.gridironit.com/
# gridiron it http://www.gridironit.com/
#
# ['363', '775', 1.0]
# digital people http://www.digitalpeople.net/
# digital people http://www.digitalpeople.net/
#
# ['377', '1576', 1.0]
# kelly http://www.kellyservices.com/
# kelly http://www.kellyservices.com/
#
# ['404', '2651', 1.0]
# mainz brady group http://www.mbg.com/
# mainz brady group http://www.mbg.com/
#
# ['541', '1438', 1.0]
# fis http://www.fisglobal.com/
# fis http://www.fisglobal.com/
#
# ['487', '1237', 1.0]
# cdm smith https://www.cdmsmith.com/
# cdm smith https://www.cdmsmith.com/
#
# ['767', '1801', 1.0]
# draper http://www.draper.com/
# draper http://www.draper.com/
#
# ['506', '278', 1.0]
# inceed http://www.inceed.com/
# inceed http://www.inceed.com/
#
# ['513', '1215', 1.0]
# rettew http://www.rettew.com/
# rettew http://www.rettew.com/
#
# ['550', '1340', 1.0]
# dropbox http://www.dropbox.com/
# dropbox http://www.dropbox.com/
#
# ['556', '1461', 1.0]
# revel it http://www.revelit.com/
# revel it http://www.revelit.com/
#
# ['567', '1270', 1.0]
# grant street group http://www.grantstreet.com/
# grant street group http://www.grantstreet.com/
#
# ['630', '2239', 1.0]
# mastech digital http://www.mastechdigital.com/
# mastech digital http://www.mastechdigital.com/
#
# ['606', '81', 1.0]
# selby jennings http://www.selbyjennings.com/
# selby jennings http://www.selbyjennings.com/
#
# ['608', '2250', 1.0]
# peterson technology partners http://www.ptechpartners.com/
# peterson technology partners http://www.ptechpartners.com/
#
# ['611', '2496', 1.0]
# modis http://www.modis.com/
# modis http://www.modis.com/
#
# ['636', '1572', 1.0]
# virtusa http://www.virtusa.com/
# virtusa http://www.virtusa.com/
#
# ['651', '1075', 0.85]
# bairesdev
# bairesdev https://www.bairesdev.com/
#
# ['669', '1923', 1.0]
# ibm http://www.ibm.com/
# ibm http://www.ibm.com/
#
# ['674', '1705', 1.0]
# gleeds http://www.gleeds.com/
# gleeds http://www.gleeds.com/
#
# ['732', '2261', 1.0]
# boeing http://www.boeing.com/
# boeing http://www.boeing.com/
#
# ['721', '1528', 1.0]
# yoh, a day & zimmermann company http://www.yoh.com/
# yoh, a day & zimmermann company http://www.yoh.com/
#
# ['736', '2472', 1.0]
# motorola solutions http://www.motorolasolutions.com/
# motorola solutions http://www.motorolasolutions.com/
#
# ['779', '2358', 1.0]
# uber http://www.uber.com/
# uber http://www.uber.com/
#
# ['780', '2386', 1.0]
# deloitte http://www.deloitte.com/
# deloitte http://www.deloitte.com/
#
# ['878', '2011', 1.0]
# xcel energy http://www.xcelenergy.com/
# xcel energy http://www.xcelenergy.com/
#
# ['888', '1585', 1.0]
# ektello http://www.ektello.com/
# ektello http://www.ektello.com/

# %%
with open(dir_ + 'linkage/g_l_linkage.csv', mode='w') as file:
    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(["glassdoor.id", "linkedin.id"])
    for row in matchPairs:
        writer.writerow((row[0], row[1]))

# %% [markdown]
# ### blocking linkedin-wikidata

# %%
bg2 = rltk.HashBlockGenerator()

block2 = bg2.generate(
    bg2.block(ds_wikidata, property_="first3title"),
    bg2.block(ds_linkedin, property_="first3title")
)

# %%
def title_string_similarity(s1, s2):
    return rltk.jaro_winkler_similarity(s1, s2)
def website_similarity2(s1, s2):
    if s1.lower() == s2.lower() and s1 != "" and s2 != "":
        return 1
    if s1 == "" and s2 == "":
        return 0.05
    if s1 == "":
        return 0.3
    if s2 == "":
        return 0.1
    return 0

# %%
MY_TRESH = 0.759

# entity linkage scoring function
def rule_based_method2(r1, r2):
    score_1 = title_string_similarity(r1.name_string, r2.name_string)
    score_2 = website_similarity2(r1.website_nohttp, r2.website_nohttp)
    if r1.name_string == "Uber Technology" and r2.name_string == "Uber":
        print(r1.website_string, r2.website_string)
        print(r1.website_nohttp, r2.website_nohttp)
        print(score_1, score_2, 0.7*score_1 + 0.3*score_2)
    total = 0.76*score_1 + 0.24*score_2
    
    return total > MY_TRESH, total, score_1, score_2

# %%
matchPairs_wl = []
for r_wikidata, r_linkedin in rltk.get_record_pairs(ds_wikidata, ds_linkedin, block=block2):
    result, confidence, score_1, score_2 = rule_based_method2(r_wikidata, r_linkedin)
    if result == True:
        matchPairs_wl.append([r_wikidata.id, r_linkedin.id, confidence, score_1, score_2])

# %%
len(matchPairs_wl)
# Out:
# 567

# %%
for ids in matchPairs_wl:
    print(ids)
    r_wikidata = ds_wikidata.get_record(ids[0])
    r_linkedin = ds_linkedin.get_record(ids[1])
    print(r_wikidata.website_string, r_wikidata.name_string)
    print(r_linkedin.website_string, r_linkedin.name_string, "\n")
# Out:
# ['http://www.wikidata.org/entity/Q4633233', '106', 0.76, 1.0, 0]
# http://www.2u.com/ 2u
# http://2u.com/ 2u
#
# ['http://www.wikidata.org/entity/Q259340', '1001', 1.0, 1.0, 1]
# https://www.7-eleven.com/ 7-eleven
# http://www.7-ELEVEn.com/ 7-eleven
#
# ['http://www.wikidata.org/entity/Q4658862', '1027', 1.0, 1.0, 1]
# http://www.aplaceformom.com/ a place for mom
# http://www.aplaceformom.com/ a place for mom
#
# ['http://www.wikidata.org/entity/Q306764', '2625', 0.896, 0.8631578947368421, 1]
# http://www.abbott.com/ abbott laboratories
# https://www.abbott.com/ abbott
#
# ['http://www.wikidata.org/entity/Q14662364', '942', 1.0, 1.0, 1]
# http://www.abbvie.com/ abbvie
# http://www.abbvie.com/ abbvie
#
# ['http://www.wikidata.org/entity/Q104290524', '2625', 0.8986666666666666, 0.8666666666666666, 1]
# https://www.abbott.com/ abbott diagnostics
# https://www.abbott.com/ abbott
#
# ['http://www.wikidata.org/entity/Q4672981', '31', 0.924, 0.9, 1]
# https://www.acehardware.com/ ace hardware
# http://www.acehardware.com/ ace hardware corporation
#
# ['http://www.wikidata.org/entity/Q4650685', '1546', 1.0, 1.0, 1]
# http://www.aciworldwide.com/ aci worldwide
# https://www.aciworldwide.com/ aci worldwide
#
# ['http://www.wikidata.org/entity/Q919300', '1838', 0.76, 1.0, 0]
# http://www.avinc.com/ aerovironment
# https://linktr.ee/aerovironment/ aerovironment
#
# ['http://www.wikidata.org/entity/Q16970526', '1828', 1.0, 1.0, 1]
# http://www.rocket.com/ aerojet rocketdyne
# http://www.rocket.com/ aerojet rocketdyne
#
# ['http://www.wikidata.org/entity/Q30263988', '290', 0.9123076923076924, 0.8846153846153847, 1]
# https://www.aesculapusa.com/ aesculap (united states)
# https://www.aesculapusa.com/ aesculap (us)
#
# ['http://www.wikidata.org/entity/Q80635', '2127', 1.0, 1.0, 1]
# https://www.airgas.com/ airgas
# http://www.airgas.com/ airgas
#
# ['http://www.wikidata.org/entity/Q64142053', '147', 0.8894545454545454, 0.8545454545454545, 1]
# https://www.airbus.com/ airbus (united states)
# http://www.airbus.com/ airbus
#
# ['http://www.wikidata.org/entity/Q107519613', '1684', 0.8841904761904762, 0.8476190476190476, 1]
# https://www.alcon.com/ alcon (united states)
# http://www.alcon.com/ alcon
#
# ['http://www.wikidata.org/entity/Q1339044', '1257', 0.7655, 0.9125, 0.3]
#  aldus
# https://www.aldi.us/ aldi usa
#
# ['http://www.wikidata.org/entity/Q4731377', '2367', 1.0, 1.0, 1]
# http://www.allegisgroup.com/ allegis group
# https://www.allegisgroup.com/ allegis group
#
# ['http://www.wikidata.org/entity/Q3884', '2070', 0.76, 1.0, 0]
# https://www.amazon.com/ amazon
# https://www.aboutamazon.com/ amazon
#
# ['http://www.wikidata.org/entity/Q16996714', '150', 0.9674285714285714, 0.9571428571428571, 1]
# http://www.amneal.com/ amneal pharmaceuticals, inc.
# http://www.amneal.com/ amneal pharmaceuticals
#
# ['http://www.wikidata.org/entity/Q4738901', '1278', 0.7813333333333333, 0.9333333333333333, 0.3]
#  amtran
# http://www.amtrak.com/ amtrak
#
# ['http://www.wikidata.org/entity/Q4753960', '134', 1.0, 1.0, 1]
# http://www.andersenwindows.com/ andersen corporation
# http://www.andersenwindows.com/ andersen corporation
#
# ['http://www.wikidata.org/entity/Q1242804', '1890', 0.9674285714285714, 0.9571428571428571, 1]
# http://www.aps.com/ arizona public service
# http://www.aps.com/ arizona public service - aps
#
# ['http://www.wikidata.org/entity/Q344935', '2440', 0.76, 1.0, 0]
# https://liveramp.com/ acxiom
# http://www.acxiom.com/ acxiom
#
# ['http://www.wikidata.org/entity/Q4686051', '1086', 1.0, 1.0, 1]
# http://www.advanceautoparts.com/ advance auto parts
# http://www.advanceautoparts.com/ advance auto parts
#
# ['http://www.wikidata.org/entity/Q30338375', '1126', 0.8841904761904762, 0.8476190476190476, 1]
# http://www.aecom.com/ aecom (united states)
# http://www.aecom.com/ aecom
#
# ['http://www.wikidata.org/entity/Q4692116', '152', 1.0, 1.0, 1]
# http://www.agenusbio.com/ agenus
# http://www.agenusbio.com/ agenus
#
# ['http://www.wikidata.org/entity/Q18148121', '1338', 1.0, 1.0, 1]
# https://www.aha.io/ aha!
# http://www.aha.io/ aha!
#
# ['http://www.wikidata.org/entity/Q2831861', '2505', 0.924, 0.9, 1]
# https://www.albertsonscompanies.com/ albertsons
# http://www.albertsonscompanies.com/ albertsons companies
#
# ['http://www.wikidata.org/entity/Q54829299', '2644', 1.0, 1.0, 1]
# https://www.alivecor.com/ alivecor
# http://www.alivecor.com/ alivecor
#
# ['http://www.wikidata.org/entity/Q644289', '1269', 1.0, 1.0, 1]
# http://www.alticeusa.com/ altice usa
# http://www.alticeusa.com/ altice usa
#
# ['http://www.wikidata.org/entity/Q73883753', '1016', 1.0, 1.0, 1]
# http://www.alteryx.com/ alteryx
# http://www.alteryx.com/ alteryx
#
# ['http://www.wikidata.org/entity/Q4743956', '2037', 0.7820849816849818, 0.9343223443223444, 0.3]
#  american health, inc.
# http://amhealthplans.com/ american health plans inc.
#
# ['http://www.wikidata.org/entity/Q4744960', '841', 0.7644621848739496, 0.9111344537815126, 0.3]
#  american seating
# http://jobs.aa.com/ american airlines
#
# ['http://www.wikidata.org/entity/Q4743669', '1415', 0.7923478260869564, 0.9478260869565217, 0.3]
#  american electric
# http://AEP.com/ american electric power
#
# ['http://www.wikidata.org/entity/Q464092', '1415', 0.76, 1.0, 0]
# https://www.aep.com/ american electric power
# http://AEP.com/ american electric power
#
# ['http://www.wikidata.org/entity/Q113084421', '608', 0.7642763197586726, 0.9108898944193061, 0.3]
#  american bantam
# https://www.americannational.com/wps/portal/amnat/home/ american national
#
# ['http://www.wikidata.org/entity/Q64141477', '2391', 0.924, 0.9, 1]
# https://www.americansystems.com/ american systems (united states)
# http://www.AmericanSystems.com/ american systems
#
# ['http://www.wikidata.org/entity/Q23130318', '2048', 0.76, 1.0, 0]
# https://www.amerigas.com/ amerigas
# http://www.amerigas.com/contact/ amerigas
#
# ['http://www.wikidata.org/entity/Q32396', '841', 0.76, 1.0, 0]
# https://www.aa.com/ american airlines
# http://jobs.aa.com/ american airlines
#
# ['http://www.wikidata.org/entity/Q4743668', '1415', 0.7923478260869564, 0.9478260869565217, 0.3]
#  american electric
# http://AEP.com/ american electric power
#
# ['http://www.wikidata.org/entity/Q19872179', '841', 0.7719843137254901, 0.921031991744066, 0.3]
#  american aerolights
# http://jobs.aa.com/ american airlines
#
# ['http://www.wikidata.org/entity/Q484930', '1858', 1.0, 1.0, 1]
# https://www.analog.com/ analog devices
# http://www.analog.com/ analog devices
#
# ['http://www.wikidata.org/entity/Q125074', '1740', 0.76, 1.0, 0]
# https://www.anheuser-busch.com/ anheuser-busch
# https://www.anheuser-busch.com/careers.html/ anheuser-busch
#
# ['http://www.wikidata.org/entity/Q4781354', '1937', 0.7885714285714285, 0.9428571428571428, 0.3]
#  applera
# http://www.apple.com/careers/ apple
#
# ['http://www.wikidata.org/entity/Q312', '1937', 0.76, 1.0, 0]
# https://www.apple.com/ apple
# http://www.apple.com/careers/ apple
#
# ['http://www.wikidata.org/entity/Q625708', '1427', 1.0, 1.0, 1]
# http://www.aramark.com/ aramark
# http://www.aramark.com/ aramark
#
# ['http://www.wikidata.org/entity/Q495054', '799', 0.9493333333333334, 0.9333333333333333, 1]
# http://www.arena.net/ arenanet
# http://www.arena.net/ arenanet llc
#
# ['http://www.wikidata.org/entity/Q5380195', '2065', 0.76, 1.0, 0]
# http://www.entercom.com/ audacy, inc.
# http://www.audacyinc.com/ audacy, inc.
#
# ['http://www.wikidata.org/entity/Q4822528', '1480', 1.0, 1.0, 1]
# http://www.aurora.aero/ aurora flight sciences
# http://www.aurora.aero/ aurora flight sciences
#
# ['http://www.wikidata.org/entity/Q101606525', '25', 0.9016470588235295, 0.8705882352941177, 1]
# http://aurora.tech/ aurora innovation
# https://aurora.tech/ aurora
#
# ['http://www.wikidata.org/entity/Q806089', '2092', 0.76, 1.0, 0]
# http://www.calif.aaa.com/ automobile club of southern california
# https://careers.ace.aaa.com/ automobile club of southern california
#
# ['http://www.wikidata.org/entity/Q690604', '2516', 1.0, 1.0, 1]
# https://www.axon.com/ axon
# http://www.axon.com/ axon
#
# ['http://www.wikidata.org/entity/Q97498224', '2516', 0.8016, 0.96, 0.3]
#  axoni
# http://www.axon.com/ axon
#
# ['http://www.wikidata.org/entity/Q810773', '1351', 1.0, 1.0, 1]
# http://www.bathandbodyworks.com/ bath & body works
# http://www.bathandbodyworks.com/ bath & body works
#
# ['http://www.wikidata.org/entity/Q810911', '24', 0.8930370370370371, 0.8592592592592593, 1]
# http://www.battelle.org/ battelle memorial institute
# http://www.Battelle.org/ battelle
#
# ['http://www.wikidata.org/entity/Q813639', '1207', 0.9039999999999999, 0.8736842105263157, 1]
# http://www.bechtel.com/ bechtel
# http://www.bechtel.com/ bechtel corporation
#
# ['http://www.wikidata.org/entity/Q479952', '2646', 0.9324444444444444, 0.9111111111111111, 1]
# http://www.beckmancoulter.com/ beckman coulter
# https://www.beckmancoulter.com/ beckman coulter diagnostics
#
# ['http://www.wikidata.org/entity/Q22077752', '2622', 0.76, 1.0, 0]
# https://www.bitgo.com/ bitgo
# http://bitgo.com/ bitgo
#
# ['http://www.wikidata.org/entity/Q4920205', '1811', 1.0, 1.0, 1]
# http://www.bv.com/ black & veatch
# https://www.bv.com/ black & veatch
#
# ['http://www.wikidata.org/entity/Q4967421', '1587', 1.0, 1.0, 1]
# https://www.brighthorizons.com/ bright horizons
# http://www.brighthorizons.com/ bright horizons
#
# ['http://www.wikidata.org/entity/Q487907', '1725', 1.0, 1.0, 1]
# https://www.bankofamerica.com/ bank of america
# https://www.bankofamerica.com/ bank of america
#
# ['http://www.wikidata.org/entity/Q2881919', '2285', 1.0, 1.0, 1]
# https://www.bankofthewest.com/ bank of the west
# http://www.bankofthewest.com/ bank of the west
#
# ['http://www.wikidata.org/entity/Q4856022', '1725', 0.7614285714285713, 0.9071428571428571, 0.3]
#  bank of america, los angeles
# https://www.bankofamerica.com/ bank of america
#
# ['http://www.wikidata.org/entity/Q815327', '958', 1.0, 1.0, 1]
# http://www.belden.com/ belden inc.
# https://www.belden.com/ belden inc.
#
# ['http://www.wikidata.org/entity/Q4882034', '145', 0.9309090909090909, 0.9090909090909091, 1]
# https://belcan.com/ belcan, llc
# https://belcan.com/ belcan
#
# ['http://www.wikidata.org/entity/Q283848', '975', 0.8830769230769231, 0.8461538461538461, 1]
# http://www.belkin.com/ belkin international, inc.
# http://www.belkin.com/ belkin
#
# ['http://www.wikidata.org/entity/Q3534309', '926', 0.76, 1.0, 0]
# http://www.benchmark.com/ benchmark
# http://www.bench.com/ benchmark
#
# ['http://www.wikidata.org/entity/Q4899911', '2344', 0.76, 1.0, 0]
# http://beyondtrust.com/ beyondtrust
# http://www.beyondtrust.com/ beyondtrust
#
# ['http://www.wikidata.org/entity/Q18205509', '395', 0.76, 1.0, 0]
# https://beyondmeat.com/ beyond meat
# http://www.beyondmeat.com/ beyond meat
#
# ['http://www.wikidata.org/entity/Q106946293', '2126', 1.0, 1.0, 1]
# http://www.bigid.com/ bigid
# http://www.bigid.com/ bigid
#
# ['http://www.wikidata.org/entity/Q668735', '2481', 0.76, 1.0, 0]
# http://BigFishGames.com/ big fish games
# http://www.bigfishgames.com/ big fish games
#
# ['http://www.wikidata.org/entity/Q4905973', '2201', 1.0, 1.0, 1]
# https://www.biglots.com/ big lots
# http://www.biglots.com/ big lots
#
# ['http://www.wikidata.org/entity/Q18205529', '1465', 0.924, 0.9, 1]
# http://www.bill.com/ bill.com
# http://www.bill.com/ bill
#
# ['http://www.wikidata.org/entity/Q107518538', '435', 0.8975151515151515, 0.8651515151515151, 1]
# https://biontech.de/ biontech (united states)
# https://biontech.de/ biontech se
#
# ['http://www.wikidata.org/entity/Q110778747', '2345', 0.9170909090909092, 0.890909090909091, 1]
# https://block.xyz/ block, inc.
# https://block.xyz/ block
#
# ['http://www.wikidata.org/entity/Q4929834', '2078', 1.0, 1.0, 1]
# http://www.blueshieldca.com/ blue shield of california
# http://www.blueshieldca.com/ blue shield of california
#
# ['http://www.wikidata.org/entity/Q56582970', '419', 0.9305142857142857, 0.9085714285714286, 1]
# http://www.blueprintmedicines.com/ blueprint medicines (united states)
# http://www.blueprintmedicines.com/ blueprint medicines
#
# ['http://www.wikidata.org/entity/Q885836', '2369', 1.0, 1.0, 1]
# https://www.blueorigin.com/ blue origin
# http://www.blueorigin.com/ blue origin
#
# ['http://www.wikidata.org/entity/Q4929019', '1474', 0.76, 1.0, 0]
# https://www.bluecrossma.com/ blue cross blue shield of massachusetts
# http://home.bluecrossma.com/ blue cross blue shield of massachusetts
#
# ['http://www.wikidata.org/entity/Q4931582', '2197', 0.76, 1.0, 0]
# https://www.mybobs.com/ bob's discount furniture
# https://mybobs.com/ bob's discount furniture
#
# ['http://www.wikidata.org/entity/Q66', '2261', 1.0, 1.0, 1]
# https://www.boeing.com/ boeing
# http://www.boeing.com/ boeing
#
# ['http://www.wikidata.org/entity/Q893221', '2394', 0.76, 1.0, 0]
# http://www.boozallen.com/ booz allen hamilton
# http://www.boozallen.com?source=SNS-17780/ booz allen hamilton
#
# ['http://www.wikidata.org/entity/Q4943790', '1508', 0.76, 1.0, 0]
# https://www.boostmobile.com/ boost mobile
# https://careers.dish.com/boostmobile/ boost mobile
#
# ['http://www.wikidata.org/entity/Q825943', '1883', 0.76, 1.0, 0]
# http://www.BorgWarner.com/ borgwarner
# http://borgwarner.com/ borgwarner
#
# ['http://www.wikidata.org/entity/Q894585', '1098', 1.0, 1.0, 1]
# http://www.bostonscientific.com/ boston scientific
# http://www.bostonscientific.com/ boston scientific
#
# ['http://www.wikidata.org/entity/Q555925', '1760', 0.9415384615384615, 0.9230769230769231, 1]
# http://www.broadcom.com/ broadcom
# http://www.broadcom.com/ broadcom inc.
#
# ['http://www.wikidata.org/entity/Q4976010', '1371', 0.9339130434782609, 0.9130434782608695, 1]
# http://www.bbinsurance.com/ brown & brown
# http://www.bbinsurance.com/ brown & brown insurance
#
# ['http://www.wikidata.org/entity/Q4827416', '1760', 0.76, 1.0, 0]
# https://jp.broadcom.com/ broadcom inc.
# http://www.broadcom.com/ broadcom inc.
#
# ['http://www.wikidata.org/entity/Q5003490', '1310', 1.0, 1.0, 1]
# https://www.buzzfeed.com/ buzzfeed
# http://www.buzzfeed.com/ buzzfeed
#
# ['http://www.wikidata.org/entity/Q5028383', '1266', 1.0, 1.0, 1]
# http://www.campingworld.com/ camping world
# https://www.campingworld.com/ camping world
#
# ['http://www.wikidata.org/entity/Q1045890', '765', 0.7596190476190476, 0.9047619047619048, 0.3]
#  cartercar
# http://www.cartier.com/ cartier
#
# ['http://www.wikidata.org/entity/Q5037190', '903', 0.76, 1.0, 0]
# http://www.carmax.com/ carmax
# http://carmax.com/ carmax
#
# ['http://www.wikidata.org/entity/Q902397', '2272', 0.76, 1.0, 0]
# https://www.cardinalhealth.com/ cardinal health
# http://cardinalhealth.com/ cardinal health
#
# ['http://www.wikidata.org/entity/Q16852011', '2082', 0.7704259259259258, 0.9189814814814814, 0.3]
#  carad.com
# https://www.cart.com/ cart.com
#
# ['http://www.wikidata.org/entity/Q1036056', '2515', 0.76, 1.0, 0]
# http://cargill.com/ cargill
# https://www.cargill.com/ cargill
#
# ['http://www.wikidata.org/entity/Q459965', '1962', 1.0, 1.0, 1]
# https://www.caterpillar.com/ caterpillar inc.
# https://www.caterpillar.com/ caterpillar inc.
#
# ['http://www.wikidata.org/entity/Q23018218', '1237', 1.0, 1.0, 1]
# http://www.cdmsmith.com/ cdm smith
# https://www.cdmsmith.com/ cdm smith
#
# ['http://www.wikidata.org/entity/Q1023155', '1448', 1.0, 1.0, 1]
# http://www.cdw.com/ cdw
# http://www.cdw.com/ cdw
#
# ['http://www.wikidata.org/entity/Q5059102', '2524', 1.0, 1.0, 1]
# https://www.centene.com/ centene corporation
# http://www.centene.com/ centene corporation
#
# ['http://www.wikidata.org/entity/Q5094438', '308', 0.9631515151515152, 0.9515151515151515, 1]
# https://www.cpchem.com/ chevron phillips chemical
# http://www.cpchem.com/ chevron phillips chemical company
#
# ['http://www.wikidata.org/entity/Q5096393', '697', 0.9105882352941176, 0.8823529411764706, 1]
# http://www.chicosfas.com/ chico's
# http://www.chicosfas.com/ chico's fas, inc.
#
# ['http://www.wikidata.org/entity/Q5011381', '2268', 1.0, 1.0, 1]
# http://www.chsinc.com/ chs inc.
# https://www.chsinc.com/ chs inc.
#
# ['http://www.wikidata.org/entity/Q93355376', '1756', 0.8733333333333334, 0.8333333333333334, 1]
# https://www.citigroup.com/ citigroup global markets
# http://www.citigroup.com/ citi
#
# ['http://www.wikidata.org/entity/Q219508', '1756', 0.9155555555555556, 0.888888888888889, 1]
# http://www.citigroup.com/ citigroup
# http://www.citigroup.com/ citi
#
# ['http://www.wikidata.org/entity/Q5123723', '547', 0.8986666666666666, 0.8666666666666666, 1]
# http://www.cityofhope.org/ city of hope national medical center
# http://www.cityofhope.org/ city of hope
#
# ['http://www.wikidata.org/entity/Q5123317', '1395', 0.76, 1.0, 0]
# http://www.citynatbank.com/ city national bank
# https://newsroom.cnb.com/?utm_medium=organicsocial&utm_source=linkedin&utm_channel=social&utmid=huxgYHDKFyzSYZr/ city national bank
#
# ['http://www.wikidata.org/entity/Q5123314', '1395', 0.76, 1.0, 0]
# https://www.cnb.com/ city national bank
# https://newsroom.cnb.com/?utm_medium=organicsocial&utm_source=linkedin&utm_channel=social&utmid=huxgYHDKFyzSYZr/ city national bank
#
# ['http://www.wikidata.org/entity/Q5130494', '126', 1.0, 1.0, 1]
# http://www.cleanharbors.com/ clean harbors
# http://www.cleanharbors.com/ clean harbors
#
# ['http://www.wikidata.org/entity/Q5013072', '478', 0.9064615384615384, 0.8769230769230769, 1]
# http://www.cna.com/ cna financial
# http://www.cna.com/ cna insurance
#
# ['http://www.wikidata.org/entity/Q1107035', '2619', 1.0, 1.0, 1]
# https://www.cognizant.com/ cognizant
# https://www.cognizant.com/ cognizant
#
# ['http://www.wikidata.org/entity/Q1113804', '2539', 0.76, 1.0, 0]
# https://www.cmcsa.com/ comcast
# https://corporate.comcast.com/ comcast
#
# ['http://www.wikidata.org/entity/Q5153675', '284', 0.7629090909090909, 0.9090909090909091, 0.3]
#  commonwealth
# http://crijobs.com/ commonwealth resources
#
# ['http://www.wikidata.org/entity/Q1114148', '2449', 0.9415384615384615, 0.9230769230769231, 1]
# https://www.comerica.com/ comerica
# http://www.comerica.com/ comerica bank
#
# ['http://www.wikidata.org/entity/Q734779', '98', 0.9348571428571428, 0.9142857142857143, 1]
# https://www.comscore.com/ comscore
# http://www.comscore.com/ comscore, inc.
#
# ['http://www.wikidata.org/entity/Q5152058', '758', 0.9284705882352942, 0.9058823529411765, 1]
# https://www.commvault.com/ commvault systems
# https://www.commvault.com/ commvault
#
# ['http://www.wikidata.org/entity/Q5152057', '1916', 1.0, 1.0, 1]
# http://www.commscope.com/ commscope
# http://www.commscope.com/ commscope
#
# ['http://www.wikidata.org/entity/Q715583', '2282', 0.905, 0.875, 1]
# https://www.costco.com/ costco
# http://www.costco.com/ costco wholesale
#
# ['http://www.wikidata.org/entity/Q5182000', '2195', 1.0, 1.0, 1]
# http://www.craneco.com/ crane co.
# http://www.craneco.com/ crane co.
#
# ['http://www.wikidata.org/entity/Q24890758', '1727', 1.0, 1.0, 1]
# https://www.crowdstrike.com/ crowdstrike
# http://www.crowdstrike.com/ crowdstrike
#
# ['http://www.wikidata.org/entity/Q692524', '1375', 1.0, 1.0, 1]
# http://www.cslbehring.com/ csl behring
# https://www.cslbehring.com/ csl behring
#
# ['http://www.wikidata.org/entity/Q624375', '2235', 0.76, 1.0, 0]
# http://cvshealth.com/ cvs health
# https://cvs.co/linkedinprofile/ cvs health
#
# ['http://www.wikidata.org/entity/Q23016736', '1107', 1.0, 1.0, 1]
# http://www.cybercoders.com/ cybercoders
# http://www.cybercoders.com/ cybercoders
#
# ['http://www.wikidata.org/entity/Q5197770', '1107', 0.7598383838383838, 0.905050505050505, 0.3]
#  cyberdreams
# http://www.cybercoders.com/ cybercoders
#
# ['http://www.wikidata.org/entity/Q16954934', '2125', 0.7596190476190476, 0.9047619047619048, 0.3]
#  california faience
# http://www.caiso.com/ california iso
#
# ['http://www.wikidata.org/entity/Q25025281', '2276', 1.0, 1.0, 1]
# https://www.calcoastcu.org/ california coast credit union
# https://www.calcoastcu.org/ california coast credit union
#
# ['http://www.wikidata.org/entity/Q4112833', '391', 0.7813333333333333, 0.9333333333333333, 0.3]
#  caleres
# http://www.calpers.ca.gov/ calpers
#
# ['http://www.wikidata.org/entity/Q5019738', '2551', 0.92704, 0.904, 1]
# http://www.calgoncarbon.com/ calgon carbon
# http://www.calgoncarbon.com/ calgon carbon corporation
#
# ['http://www.wikidata.org/entity/Q99482082', '1819', 1.0, 1.0, 1]
# https://www.canoo.com/ canoo
# http://www.canoo.com/ canoo
#
# ['http://www.wikidata.org/entity/Q5032745', '1922', 0.76, 1.0, 0]
# http://www.ittcannon.com/ cannon
# http://www.cannoncorp.us/ cannon
#
# ['http://www.wikidata.org/entity/Q1034654', '2639', 1.0, 1.0, 1]
# https://www.capitalone.com/ capital one
# http://www.capitalone.com/ capital one
#
# ['http://www.wikidata.org/entity/Q1066028', '1635', 0.9298461538461539, 0.9076923076923077, 1]
# https://www.schwab.com/ charles schwab corporation
# http://www.schwab.com/ charles schwab
#
# ['http://www.wikidata.org/entity/Q5116536', '897', 0.9392, 0.92, 1]
# http://www.churchdwight.com/ church & dwight
# http://www.churchdwight.com/ church & dwight co., inc.
#
# ['http://www.wikidata.org/entity/Q642271', '2482', 1.0, 1.0, 1]
# http://www.cigna.com/ cigna
# http://www.cigna.com/ cigna
#
# ['http://www.wikidata.org/entity/Q3268010', '2202', 1.0, 1.0, 1]
# https://www.circlek.com/ circle k
# http://www.circlek.com/ circle k
#
# ['http://www.wikidata.org/entity/Q1067998', '1872', 1.0, 1.0, 1]
# http://www.cirrus.com/ cirrus logic
# http://www.cirrus.com/ cirrus logic
#
# ['http://www.wikidata.org/entity/Q17007851', '58', 1.0, 1.0, 1]
# https://www.circle.com/ circle
# http://www.circle.com/ circle
#
# ['http://www.wikidata.org/entity/Q5145789', '1612', 1.0, 1.0, 1]
# http://www.collabera.com/ collabera
# http://www.collabera.com/ collabera
#
# ['http://www.wikidata.org/entity/Q30283053', '924', 0.9060993343573989, 0.8764464925755249, 1]
# http://www.collagenmatrix.com/ collagen matrix (united states)
# http://www.CollagenMatrix.com/ collagen matrix, inc.
#
# ['http://www.wikidata.org/entity/Q19367457', '2129', 0.7722857142857142, 0.9214285714285715, 0.3]
#  collins
# https://www.colliers.com/ colliers
#
# ['http://www.wikidata.org/entity/Q1127527', '1699', 0.7657604617604618, 0.9128427128427129, 0.3]
#  consolidated aircraft
# http://www.consolidatedanalytics.com/ consolidated analytics
#
# ['http://www.wikidata.org/entity/Q5165293', '1882', 0.7636, 0.91, 0.3]
#  continental illinois
# http://www.continental-careers.com/ continental
#
# ['http://www.wikidata.org/entity/Q5163620', '1314', 1.0, 1.0, 1]
# http://www.constantcontact.com/ constant contact
# http://www.constantcontact.com/ constant contact
#
# ['http://www.wikidata.org/entity/Q1123399', '937', 0.9544, 0.9400000000000001, 1]
# https://www.conagrabrands.com/ conagra brands, inc.
# http://www.conagrabrands.com/ conagra brands
#
# ['http://www.wikidata.org/entity/Q1129847', '930', 0.76, 1.0, 0]
# https://coopertire.com/ cooper tire & rubber company
# https://jobs.goodyear.com/content/Cooper-Tire-Careers/?locale=en_US/ cooper tire & rubber company
#
# ['http://www.wikidata.org/entity/Q5177183', '2341', 0.7663636363636364, 0.9136363636363637, 0.3]
#  countrymark
# http://www.countrybank.com/ country bank
#
# ['http://www.wikidata.org/entity/Q5179898', '1473', 1.0, 1.0, 1]
# http://coxmediagroup.com/ cox media group
# http://coxmediagroup.com/ cox media group
#
# ['http://www.wikidata.org/entity/Q5185100', '1618', 0.76, 1.0, 0]
# http://www.cricut.com/ cricut
# https://cricut.com/blog/what-is-cricut?utm_campaign=brand&utm_medium=social&utm_source=linkedin&utm_content=evergreen&utm_term=bio/ cricut
#
# ['http://www.wikidata.org/entity/Q5192235', '853', 1.0, 1.0, 1]
# https://www.cubic.com/ cubic corporation
# http://www.cubic.com/ cubic corporation
#
# ['http://www.wikidata.org/entity/Q188920', '171', 0.76, 1.0, 0]
# https://zh.delta.com/ delta air lines
# http://www.delta.com/ delta air lines
#
# ['http://www.wikidata.org/entity/Q27500963', '2634', 1.0, 1.0, 1]
# http://www.delltechnologies.com/ dell technologies
# http://www.delltechnologies.com/ dell technologies
#
# ['http://www.wikidata.org/entity/Q48800016', '969', 1.0, 1.0, 1]
# http://www.desktopmetal.com/ desktop metal
# http://www.desktopmetal.com/ desktop metal
#
# ['http://www.wikidata.org/entity/Q68896342', '1645', 0.7722857142857142, 0.9214285714285715, 0.3]
#  digitek
# http://www.godigitive.com/ digitive
#
# ['http://www.wikidata.org/entity/Q5281735', '1681', 1.0, 1.0, 1]
# https://www.discounttire.com/ discount tire
# http://www.discounttire.com/ discount tire
#
# ['http://www.wikidata.org/entity/Q16991871', '270', 0.8758666666666667, 0.8366666666666667, 1]
# http://www.djoglobal.com/ djo global
# http://www.djoglobal.com/ djo
#
# ['http://www.wikidata.org/entity/Q5227494', '837', 0.7737333333333332, 0.9233333333333332, 0.3]
#  datastorm technologies, inc.
# http://www.datasoft-tech.com/ datasoft technologies
#
# ['http://www.wikidata.org/entity/Q5272601', '1022', 0.76, 1.0, 0]
# https://www.dickssportinggoods.com/ dick's sporting goods
# http://www.dickssportinggoods.jobs/ dick's sporting goods
#
# ['http://www.wikidata.org/entity/Q1220078', '1927', 0.76, 1.0, 0]
# http://www.dieboldnixdorf.com/en-us/ diebold nixdorf
# http://DieboldNixdorf.com/ diebold nixdorf
#
# ['http://www.wikidata.org/entity/Q1056839', '814', 0.76, 1.0, 0]
# https://DirecTV.com/ directv
# http://direc.tv/about/ directv
#
# ['http://www.wikidata.org/entity/Q5283771', '353', 0.9206222222222222, 0.8955555555555555, 1]
# http://www.divx.com/ divx, inc.
# http://www.divx.com/ divx, llc
#
# ['http://www.wikidata.org/entity/Q5287613', '2624', 1.0, 1.0, 1]
# http://www.docusign.com/ docusign
# http://www.docusign.com/ docusign
#
# ['http://www.wikidata.org/entity/Q5289230', '2206', 0.9408888888888889, 0.9222222222222222, 1]
# https://www.dollartree.com/ dollar tree
# http://www.dollartree.com/ dollar tree stores
#
# ['http://www.wikidata.org/entity/Q21015679', '1110', 0.7610666666666667, 0.9066666666666667, 0.3]
#  donda
# http://www.donan.com/ donan
#
# ['http://www.wikidata.org/entity/Q16974527', '1569', 1.0, 1.0, 1]
# http://www.dovercorporation.com/ dover corporation
# http://www.dovercorporation.com/ dover corporation
#
# ['http://www.wikidata.org/entity/Q855639', '153', 0.8492666666666666, 0.8016666666666666, 1]
# http://www.dow.com/ dow chemical company
# http://www.dow.com/ dow
#
# ['http://www.wikidata.org/entity/Q99541306', '500', 1.0, 1.0, 1]
# https://www.dreamhaven.com/ dreamhaven
# http://www.dreamhaven.com/ dreamhaven
#
# ['http://www.wikidata.org/entity/Q15589464', '1340', 0.9366666666666668, 0.9166666666666667, 1]
# http://www.dropbox.com/ dropbox inc.
# http://www.dropbox.com/ dropbox
#
# ['http://www.wikidata.org/entity/Q1264404', '1879', 0.920695652173913, 0.8956521739130435, 1]
# https://www.duke-energy.com/ duke energy
# http://www.duke-energy.com/ duke energy corporation
#
# ['http://www.wikidata.org/entity/Q2918660', '494', 0.76, 1.0, 0]
# https://www.duolingo.com/ duolingo
# https://www.duolingo.com/careers/ duolingo
#
# ['http://www.wikidata.org/entity/Q5319205', '240', 0.9348571428571428, 0.9142857142857143, 1]
# http://www.dynetics.com/ dynetics
# http://www.dynetics.com/ dynetics, inc.
#
# ['http://www.wikidata.org/entity/Q869106', '585', 0.76, 1.0, 0]
# https://www.easports.com/ ea sports
# http://www.easports.com/careers/ ea sports
#
# ['http://www.wikidata.org/entity/Q1282031', '1124', 1.0, 1.0, 1]
# http://www.ecolab.com/ ecolab
# http://www.ecolab.com/ ecolab
#
# ['http://www.wikidata.org/entity/Q50040882', '1488', 0.9351616631430585, 0.9146863988724454, 1]
# http://www.edgewaterit.com/ edgewater federal solutions (united states)
# http://www.edgewaterit.com/ edgewater federal solutions, inc.
#
# ['http://www.wikidata.org/entity/Q1335585', '2507', 0.9145, 0.8875, 1]
# http://www.emerson.com/ emerson electric
# http://www.emerson.com/ emerson
#
# ['http://www.wikidata.org/entity/Q5323729', '2291', 1.0, 1.0, 1]
# http://www.ensco.com/ ensco, inc.
# https://www.ensco.com/ ensco, inc.
#
# ['http://www.wikidata.org/entity/Q28155562', '1533', 0.76, 1.0, 0]
# http://www.envisionhealthcare.com/ envision healthcare
# https://www.envisionhealth.com/ envision healthcare
#
# ['http://www.wikidata.org/entity/Q5380965', '1305', 0.7668571428571428, 0.9142857142857143, 0.3]
#  envi
# https://www.envistacorp.com/ envista
#
# ['http://www.wikidata.org/entity/Q28134235', '2110', 0.7629090909090909, 0.9090909090909091, 0.3]
#  envigo
# https://www.envigo.com/ envigo ++++
#
# ['http://www.wikidata.org/entity/Q115052187', '79', 0.7771111111111111, 0.9277777777777778, 0.3]
#  envizions
# http://www.envision.com/ envision
#
# ['http://www.wikidata.org/entity/Q5382468', '2331', 0.8986666666666666, 0.8666666666666666, 1]
# http://www.epic.com/ epic systems
# https://www.epic.com/ epic
#
# ['http://www.wikidata.org/entity/Q4655171', '2280', 0.924, 0.9, 1]
# https://www.equitable.com/ equitable holdings
# http://www.equitable.com/ equitable
#
# ['http://www.wikidata.org/entity/Q5421507', '1977', 0.76, 1.0, 0]
# http://exponent.com/ exponent
# http://www.exponent.com/ exponent
#
# ['http://www.wikidata.org/entity/Q8085893', '2560', 0.76, 1.0, 0]
# https://www.expediagroup.com/ expedia group
# https://careers.expediagroup.com/ expedia group
#
# ['http://www.wikidata.org/entity/Q1384784', '2162', 1.0, 1.0, 1]
# http://www.express.com/ express
# http://www.express.com/ express
#
# ['http://www.wikidata.org/entity/Q64141604', '2229', 0.9341812612612613, 0.9133963963963965, 1]
# https://www.exptechinc.com/ expedition technology (united states)
# http://www.exptechinc.com/ expedition technology inc
#
# ['http://www.wikidata.org/entity/Q3046549', '2335', 1.0, 1.0, 1]
# https://www.eastwestbank.com/ east west bank
# http://www.eastwestbank.com/ east west bank
#
# ['http://www.wikidata.org/entity/Q899022', '1165', 0.8923333333333334, 0.8583333333333334, 1]
# http://www.eastman.com/ eastman chemical company
# http://www.eastman.com/ eastman
#
# ['http://www.wikidata.org/entity/Q677488', '2166', 0.9565714285714285, 0.9428571428571428, 1]
# https://www.elevancehealth.com/ elevance health, inc.
# https://www.elevancehealth.com/ elevance health
#
# ['http://www.wikidata.org/entity/Q5368366', '2027', 1.0, 1.0, 1]
# https://www.elwyn.org/ elwyn
# http://www.elwyn.org/ elwyn
#
# ['http://www.wikidata.org/entity/Q106589740', '1946', 1.0, 1.0, 1]
# https://www.enderamotors.com/ endera
# http://www.enderamotors.com/ endera
#
# ['http://www.wikidata.org/entity/Q5376884', '834', 0.832, 1.0, 0.3]
#  energysolutions
# http://www.energysolutions.com/ energysolutions
#
# ['http://www.wikidata.org/entity/Q1045778', '2564', 0.76, 1.0, 0]
# https://www.esri.com/zh-cn/home/ esri
# https://www.esri.com/en-us/about/about-esri/ esri
#
# ['http://www.wikidata.org/entity/Q7893563', '2417', 1.0, 1.0, 1]
# http://www.essendant.com/ essendant
# http://www.essendant.com/ essendant
#
# ['http://www.wikidata.org/entity/Q1353939', '1255', 1.0, 1.0, 1]
# https://www.etsy.com/ etsy
# http://www.etsy.com/ etsy
#
# ['http://www.wikidata.org/entity/Q26185632', '1825', 0.76, 1.0, 0]
# http://www.evoqua.com/en/ evoqua water technologies
# https://www.evoqua.com/ evoqua water technologies
#
# ['http://www.wikidata.org/entity/Q4921457', '1021', 0.76, 1.0, 0]
# http://www.evolvewrestling.com/ evolve
# https://evolve.com/ evolve
#
# ['http://www.wikidata.org/entity/Q5422162', '280', 1.0, 1.0, 1]
# http://www.extraspace.com/ extra space storage
# http://www.extraspace.com/ extra space storage
#
# ['http://www.wikidata.org/entity/Q34045622', '719', 1.0, 1.0, 1]
# https://www.fastly.com/ fastly
# http://www.fastly.com/ fastly
#
# ['http://www.wikidata.org/entity/Q5458941', '802', 0.76, 1.0, 0]
# http://www.flexcar.com:80/ flexcar
# http://www.flexcar.com/ flexcar
#
# ['http://www.wikidata.org/entity/Q16838618', '2100', 1.0, 1.0, 1]
# https://www.fleetcor.com/ fleetcor
# http://www.fleetcor.com/ fleetcor
#
# ['http://www.wikidata.org/entity/Q30338111', '1935', 0.8705185185185185, 0.8296296296296296, 1]
# https://flex.com/ flextronics (united states)
# https://flex.com/ flex
#
# ['http://www.wikidata.org/entity/Q1430331', '1355', 0.9131428571428571, 0.8857142857142858, 1]
# http://www.flowserve.com/ flowserve
# http://www.flowserve.com/ flowserve corporation
#
# ['http://www.wikidata.org/entity/Q5461681', '1472', 0.7813333333333333, 0.9333333333333333, 0.3]
#  florida tile
# http://www.floridablue.com/ florida blue
#
# ['http://www.wikidata.org/entity/Q1391731', '1476', 1.0, 1.0, 1]
# http://www.fmglobal.com/ fm global
# http://www.fmglobal.com/ fm global
#
# ['http://www.wikidata.org/entity/Q5491225', '2348', 0.7668571428571428, 0.9142857142857143, 0.3]
#  franklin
# http://www.franklinfitch.com/ franklin fitch
#
# ['http://www.wikidata.org/entity/Q18150640', '2295', 1.0, 1.0, 1]
# https://www.fanaticsinc.com/ fanatics, inc.
# http://www.fanaticsinc.com/ fanatics, inc.
#
# ['http://www.wikidata.org/entity/Q175391', '600', 1.0, 1.0, 1]
# https://www.fender.com/ fender musical instruments corporation
# http://www.fender.com/ fender musical instruments corporation
#
# ['http://www.wikidata.org/entity/Q5444235', '1273', 1.0, 1.0, 1]
# http://www.ferguson.com/ ferguson enterprises
# http://www.ferguson.com/ ferguson enterprises
#
# ['http://www.wikidata.org/entity/Q1411292', '2602', 1.0, 1.0, 1]
# https://www.fidelity.com/ fidelity investments
# http://www.fidelity.com/ fidelity investments
#
# ['http://www.wikidata.org/entity/Q5453752', '2241', 1.0, 1.0, 1]
# http://www.firstrepublic.com/ first republic bank
# http://www.firstrepublic.com/ first republic bank
#
# ['http://www.wikidata.org/entity/Q5453875', '129', 0.76, 1.0, 0]
# http://www.firsttennessee.com/ first horizon bank
# http://www.firsthorizon.com/ first horizon bank
#
# ['http://www.wikidata.org/entity/Q5452292', '2403', 0.7625142857142857, 0.9085714285714286, 0.3]
#  first american national bank
# http://www.firstam.com/ first american title
#
# ['http://www.wikidata.org/entity/Q1138888', '1350', 1.0, 1.0, 1]
# http://www.firstsolar.com/ first solar
# http://www.firstsolar.com/ first solar
#
# ['http://www.wikidata.org/entity/Q5452733', '1276', 0.9494400000000001, 0.9334736842105263, 1]
# https://www.firstcitizens.com/ first citizens bancshares
# http://www.firstcitizens.com/ first citizens bank
#
# ['http://www.wikidata.org/entity/Q104480762', '1824', 0.9161379310344827, 0.889655172413793, 1]
# https://www.firstquality.com/ first quality (united states)
# http://www.firstquality.com/ first quality
#
# ['http://www.wikidata.org/entity/Q17492679', '1792', 0.76, 1.0, 0]
# https://firefly.com/ firefly aerospace
# http://www.firefly.com/ firefly aerospace
#
# ['http://www.wikidata.org/entity/Q5452290', '2403', 0.9245846153846153, 0.9007692307692308, 1]
# http://www.firstam.com/ first american corporation
# http://www.firstam.com/ first american title
#
# ['http://www.wikidata.org/entity/Q1420513', '1532', 1.0, 1.0, 1]
# http://www.fiserv.com/ fiserv
# http://www.fiserv.com/ fiserv
#
# ['http://www.wikidata.org/entity/Q871325', '1724', 0.8810839160839161, 0.8435314685314685, 1]
# http://www.fitchratings.com/ fitch group
# http://www.fitchratings.com/ fitch ratings
#
# ['http://www.wikidata.org/entity/Q5455836', '1013', 1.0, 1.0, 1]
# https://www.fivebelow.com/ five below
# http://www.fivebelow.com/ five below
#
# ['http://www.wikidata.org/entity/Q5457038', '28', 1.0, 1.0, 1]
# http://www.flagstar.com/ flagstar bank
# http://www.flagstar.com/ flagstar bank
#
# ['http://www.wikidata.org/entity/Q63335', '637', 1.0, 1.0, 1]
# https://www.footlocker-inc.com/ foot locker
# https://www.footlocker-inc.com/ foot locker
#
# ['http://www.wikidata.org/entity/Q1435950', '227', 1.0, 1.0, 1]
# http://www.FoodLion.com/ food lion
# http://www.foodlion.com/ food lion
#
# ['http://www.wikidata.org/entity/Q5470170', '1378', 0.7632380952380952, 0.9095238095238095, 0.3]
#  formfit
# http://www.formic.co/ formic
#
# ['http://www.wikidata.org/entity/Q44294', '2224', 0.76, 1.0, 0]
# http://www.ford.com/ ford motor company
# https://corporate.ford.com/careers/ ford motor company
#
# ['http://www.wikidata.org/entity/Q1453620', '1145', 0.76, 1.0, 0]
# http://www.fcx.com/ freeport-mcmoran
# http://www.FMJobs.com/ freeport-mcmoran
#
# ['http://www.wikidata.org/entity/Q5509271', '493', 1.0, 1.0, 1]
# https://www.funko.com/ funko
# http://www.funko.com/ funko
#
# ['http://www.wikidata.org/entity/Q5512817', '643', 1.0, 1.0, 1]
# http://www.gaf.com/ gaf
# http://www.gaf.com/ gaf
#
# ['http://www.wikidata.org/entity/Q5512830', '1196', 0.76, 1.0, 0]
# http://www.gaiconsultants.com/ gai consultants, inc.
# http://gaiconsultants.com/ gai consultants, inc.
#
# ['http://www.wikidata.org/entity/Q1152374', '2466', 1.0, 1.0, 1]
# http://www.gehealthcare.com/ ge healthcare
# http://www.gehealthcare.com/ ge healthcare
#
# ['http://www.wikidata.org/entity/Q30256711', '1123', 0.9565714285714285, 0.9428571428571428, 1]
# http://www.geiconsultants.com/ gei consultants
# http://www.geiconsultants.com/ gei consultants, inc.
#
# ['http://www.wikidata.org/entity/Q1498689', '1607', 0.76, 1.0, 0]
# https://www.geico.com/ geico
# http://www.geico.jobs/ geico
#
# ['http://www.wikidata.org/entity/Q3100834', '672', 1.0, 1.0, 1]
# http://www.gensler.com/ gensler
# http://www.gensler.com/ gensler
#
# ['http://www.wikidata.org/entity/Q1501629', '421', 0.7772410256410256, 0.9279487179487179, 0.3]
#  general magic
# http://ga.com/ general atomics
#
# ['http://www.wikidata.org/entity/Q1501629', '161', 0.7618461538461538, 0.9076923076923077, 0.3]
#  general magic
# http://www.generalmills.com/ general mills
#
# ['http://www.wikidata.org/entity/Q4272111', '2441', 0.776043956043956, 0.9263736263736264, 0.3]
#  general foods
# http://www.gm.com/ general motors
#
# ['http://www.wikidata.org/entity/Q19878385', '421', 0.7695111111111111, 0.9177777777777778, 0.3]
#  general automation
# http://ga.com/ general atomics
#
# ['http://www.wikidata.org/entity/Q1501547', '421', 0.76, 1.0, 0]
# http://www.ga.com/ general atomics
# http://ga.com/ general atomics
#
# ['http://www.wikidata.org/entity/Q5533818', '1052', 0.76, 1.0, 0]
# http://www.genpt.com/ genuine parts company
# http://genpt.com/ genuine parts company
#
# ['http://www.wikidata.org/entity/Q112874402', '2441', 0.7864, 0.9400000000000001, 0.3]
#  general motors china
# http://www.gm.com/ general motors
#
# ['http://www.wikidata.org/entity/Q30282511', '646', 0.7662702702702703, 0.9135135135135135, 0.3]
#  geosyntec consultants (united states)
# https://www.geosyntec.com/ geosyntec consultants
#
# ['http://www.wikidata.org/entity/Q43895668', '1160', 0.9014128851540615, 0.8702801120448178, 1]
# https://www.geoengineers.com/ geoengineers (united states)
# http://www.geoengineers.com/ geoengineers inc.
#
# ['http://www.wikidata.org/entity/Q5547834', '1847', 1.0, 1.0, 1]
# http://www.gtri.gatech.edu/ georgia tech research institute
# http://www.gtri.gatech.edu/ georgia tech research institute
#
# ['http://www.wikidata.org/entity/Q1509282', '1998', 0.9680000000000001, 0.9578947368421054, 1]
# https://www.gp.com/ georgia-pacific
# http://www.gp.com/ georgia-pacific llc
#
# ['http://www.wikidata.org/entity/Q30640316', '1244', 1.0, 1.0, 1]
# https://www.goodrx.com/ goodrx
# http://www.goodrx.com/ goodrx
#
# ['http://www.wikidata.org/entity/Q95', '2577', 0.76, 1.0, 0]
# https://about.google/ google
# https://goo.gle/3m1IN7m/ google
#
# ['http://www.wikidata.org/entity/Q174198', '193', 0.76, 1.0, 0]
# https://www.gartner.com/ gartner
# https://gtnr.it/3vpPW81/ gartner
#
# ['http://www.wikidata.org/entity/Q1520122', '23', 1.0, 1.0, 1]
# https://www.gettyimages.com/ getty images
# http://www.gettyimages.com/ getty images
#
# ['http://www.wikidata.org/entity/Q663596', '385', 1.0, 1.0, 1]
# https://www.gilead.com/ gilead sciences
# http://www.gilead.com/ gilead sciences
#
# ['http://www.wikidata.org/entity/Q21463101', '1238', 1.0, 1.0, 1]
# https://www.goguardian.com/ goguardian
# http://www.goguardian.com/ goguardian
#
# ['http://www.wikidata.org/entity/Q5597139', '898', 0.9197777777777778, 0.8944444444444445, 1]
# http://www.graphicpkg.com/ graphic packaging
# http://www.graphicpkg.com/ graphic packaging international, llc
#
# ['http://www.wikidata.org/entity/Q17019647', '2643', 1.0, 1.0, 1]
# https://www.grubhub.com/ grubhub
# http://www.grubhub.com/ grubhub
#
# ['http://www.wikidata.org/entity/Q3118790', '1786', 1.0, 1.0, 1]
# http://www.guardian.com/ guardian industries
# http://www.guardian.com/ guardian industries
#
# ['http://www.wikidata.org/entity/Q1554299', '1952', 1.0, 1.0, 1]
# http://www.gulfstream.com/ gulfstream aerospace
# www.gulfstream.com/ gulfstream aerospace
#
# ['http://www.wikidata.org/entity/Q5627799', '2632', 1.0, 1.0, 1]
# https://www.hrblock.com/ h&r block
# https://www.hrblock.com/ h&r block
#
# ['http://www.wikidata.org/entity/Q5643474', '869', 0.8769523809523809, 0.8380952380952381, 1]
# http://www.Halozyme.com/ halozyme therapeutics
# http://www.halozyme.com/ halozyme, inc.
#
# ['http://www.wikidata.org/entity/Q5643026', '2198', 0.7722857142857142, 0.9214285714285715, 0.3]
#  hallmark guitars
# https://careers.hallmark.com/ hallmark cards
#
# ['http://www.wikidata.org/entity/Q1521910', '2198', 0.76, 1.0, 0]
# http://www.hallmark.com/ hallmark cards
# https://careers.hallmark.com/ hallmark cards
#
# ['http://www.wikidata.org/entity/Q64143083', '2413', 0.8614583333333333, 0.8177083333333334, 1]
# https://www.hcltech.com/ hcl technologies (united states)
# http://www.hcltech.com/ hcltech
#
# ['http://www.wikidata.org/entity/Q5629257', '1387', 0.8817777777777777, 0.8444444444444443, 1]
# http://www.hdrinc.com/ hdr, inc.
# http://www.hdrinc.com/ hdr
#
# ['http://www.wikidata.org/entity/Q1615684', '880', 1.0, 1.0, 1]
# http://www.hess.com/ hess corporation
# https://www.hess.com/ hess corporation
#
# ['http://www.wikidata.org/entity/Q5637027', '825', 0.8986666666666666, 0.8666666666666666, 1]
# http://www.hach.com/ hach company
# http://www.hach.com/ hach
#
# ['http://www.wikidata.org/entity/Q16994851', '685', 0.7939999999999999, 0.95, 0.3]
#  harrison
# http://www.harriscompany.com/ harris
#
# ['http://www.wikidata.org/entity/Q15109880', '2316', 0.7735384615384615, 0.9230769230769231, 0.3]
#  harmonic inc.
# https://www.harmonicinc.com/ harmonic
#
# ['http://www.wikidata.org/entity/Q1585599', '815', 0.9460645161290323, 0.9290322580645162, 1]
# http://www.harman.com/ harman international industries
# http://www.harman.com/ harman international
#
# ['http://www.wikidata.org/entity/Q5685404', '980', 0.7618461538461538, 0.9076923076923077, 0.3]
#  haworth press
# http://www.haworth.com/ haworth
#
# ['http://www.wikidata.org/entity/Q305249', '980', 1.0, 1.0, 1]
# http://www.haworth.com/ haworth
# http://www.haworth.com/ haworth
#
# ['http://www.wikidata.org/entity/Q5721418', '316', 0.9556666666666667, 0.9416666666666667, 1]
# http://www.henryford.com/ henry ford health system
# http://www.henryford.com/ henry ford health
#
# ['http://www.wikidata.org/entity/Q114487859', '595', 1.0, 1.0, 1]
# https://www.hercrentals.com/ herc rentals
# http://www.HercRentals.com/ herc rentals
#
# ['http://www.wikidata.org/entity/Q19923099', '2591', 0.76, 1.0, 0]
# https://www.hpe.com/ hewlett packard enterprise
# http://hpe.com/ hewlett packard enterprise
#
# ['http://www.wikidata.org/entity/Q5881864', '1510', 0.76, 1.0, 0]
# http://www.hollyfrontier.com/ hollyfrontier
# http://www.hfsinclair.com/ hollyfrontier
#
# ['http://www.wikidata.org/entity/Q1626480', '908', 1.0, 1.0, 1]
# http://www.hondajet.com/ honda aircraft company
# http://www.hondajet.com/ honda aircraft company
#
# ['http://www.wikidata.org/entity/Q1626772', '1980', 0.928797423510467, 0.9063123993558776, 1]
# http://www.ohio.honda.com/ honda of america manufacturing
# http://www.ohio.honda.com/ honda of america mfg., inc.
#
# ['http://www.wikidata.org/entity/Q898208', '1826', 0.76, 1.0, 0]
# http://honeywell.com/ honeywell
# http://www.honeywell.com/ honeywell
#
# ['http://www.wikidata.org/entity/Q4543160', '1877', 1.0, 1.0, 1]
# https://www.honeybeerobotics.com/ honeybee robotics
# http://www.honeybeerobotics.com/ honeybee robotics
#
# ['http://www.wikidata.org/entity/Q1410137', '1539', 1.0, 1.0, 1]
# https://www.hl.com/ houlihan lokey
# http://www.HL.com/ houlihan lokey
#
# ['http://www.wikidata.org/entity/Q21036456', '2493', 1.0, 1.0, 1]
# http://www.hubbell.com/ hubbell incorporated
# https://www.hubbell.com/ hubbell incorporated
#
# ['http://www.wikidata.org/entity/Q910866', '2312', 0.76, 1.0, 0]
# https://www.humana.com/ humana
# https://careers.humana.com/ humana
#
# ['http://www.wikidata.org/entity/Q798819', '100', 0.8983743589743589, 0.8662820512820513, 1]
# https://www.huntington.com/ huntington bank
# http://www.huntington.com/ huntington national bank
#
# ['http://www.wikidata.org/entity/Q37156', '1923', 1.0, 1.0, 1]
# https://www.ibm.com/ ibm
# http://www.ibm.com/ ibm
#
# ['http://www.wikidata.org/entity/Q1662481', '1628', 0.76, 1.0, 0]
# http://www.ihs.com/ ihs markit
# http://www.ihsmarkit.com/ ihs markit
#
# ['http://www.wikidata.org/entity/Q17101669', '484', 1.0, 1.0, 1]
# http://www.insomniac.com/ insomniac events
# http://www.insomniac.com/ insomniac events
#
# ['http://www.wikidata.org/entity/Q202972', '1800', 1.0, 1.0, 1]
# http://www.internationalpaper.com/ international paper
# http://www.internationalpaper.com/ international paper
#
# ['http://www.wikidata.org/entity/Q72853350', '2337', 0.7783529411764706, 0.9294117647058824, 0.3]
#  international art
# http://www.internationalsos.com/ international sos
#
# ['http://www.wikidata.org/entity/Q72853350', '1800', 0.7990588235294118, 0.9566563467492261, 0.3]
#  international art
# http://www.internationalpaper.com/ international paper
#
# ['http://www.wikidata.org/entity/Q16997098', '9', 0.7700307692307692, 0.9184615384615384, 0.3]
#  intelligen
# http://www.intellibridge.us/ intellibridge
#
# ['http://www.wikidata.org/entity/Q16966068', '2337', 0.7691034482758621, 0.9172413793103449, 0.3]
#  international resources group
# http://www.internationalsos.com/ international sos
#
# ['http://www.wikidata.org/entity/Q1318848', '474', 1.0, 1.0, 1]
# https://www.intuit.com/ intuit
# https://www.intuit.com/ intuit
#
# ['http://www.wikidata.org/entity/Q64141721', '1148', 0.8986666666666666, 0.8666666666666666, 1]
# http://www.intertek.com/ intertek (united states)
# http://www.intertek.com/ intertek
#
# ['http://www.wikidata.org/entity/Q6053637', '2337', 0.7611328976034858, 0.9067538126361656, 0.3]
#  international steel company
# http://www.internationalsos.com/ international sos
#
# ['http://www.wikidata.org/entity/Q248', '1917', 0.8927058823529411, 0.8588235294117647, 1]
# https://www.intel.com/ intel
# http://www.intel.com/ intel corporation
#
# ['http://www.wikidata.org/entity/Q726580', '1148', 0.7792222222222221, 0.9305555555555555, 0.3]
#  intertype
# http://www.intertek.com/ intertek
#
# ['http://www.wikidata.org/entity/Q3305345', '2457', 1.0, 1.0, 1]
# http://www.internetbrands.com/ internet brands
# http://www.internetbrands.com/ internet brands
#
# ['http://www.wikidata.org/entity/Q1070755', '2183', 0.7644444444444444, 0.9111111111111111, 0.3]
#  ion storm
# http://www.ionsolar.com/ ion solar
#
# ['http://www.wikidata.org/entity/Q19881140', '1487', 0.9463529411764706, 0.9294117647058824, 1]
# http://www.ipc.com/ ipc systems
# http://www.ipc.com/ ipc systems, inc.
#
# ['http://www.wikidata.org/entity/Q305473', '1633', 1.0, 1.0, 1]
# https://www.iqvia.com/ iqvia
# https://www.iqvia.com/ iqvia
#
# ['http://www.wikidata.org/entity/Q85769855', '2483', 1.0, 1.0, 1]
# http://www.invitationhomes.com/ invitation homes
# https://www.invitationhomes.com/ invitation homes
#
# ['http://www.wikidata.org/entity/Q5923178', '1293', 0.9170909090909092, 0.890909090909091, 1]
# http://www.itron.com/ itron
# http://www.itron.com/ itron, inc.
#
# ['http://www.wikidata.org/entity/Q3156864', '573', 0.76, 1.0, 0]
# http://www.jbtcorporation.com/ jbt corporation
# https://www.jbtc.com/ jbt corporation
#
# ['http://www.wikidata.org/entity/Q192314', '2555', 0.9544, 0.9400000000000001, 1]
# http://www.jpmorganchase.com/ jpmorgan chase
# http://www.jpmorganchase.com/ jpmorgan chase & co.
#
# ['http://www.wikidata.org/entity/Q6119812', '2286', 0.7712, 0.92, 0.3]
#  jacobson's
# http://www.jacobs.com/ jacobs
#
# ['http://www.wikidata.org/entity/Q3157622', '2286', 0.886, 0.85, 1]
# http://www.jacobs.com/ jacobs engineering group
# http://www.jacobs.com/ jacobs
#
# ['http://www.wikidata.org/entity/Q6119784', '2286', 0.7629090909090909, 0.9090909090909091, 0.3]
#  jacobs wind
# http://www.jacobs.com/ jacobs
#
# ['http://www.wikidata.org/entity/Q41568532', '2286', 0.8894545454545454, 0.8545454545454545, 1]
# http://www.jacobs.com/ jacobs (united states)
# http://www.jacobs.com/ jacobs
#
# ['http://www.wikidata.org/entity/Q4474231', '753', 1.0, 1.0, 1]
# http://www.jakks.com/ jakks pacific
# http://www.jakks.com/ jakks pacific
#
# ['http://www.wikidata.org/entity/Q19654979', '2389', 1.0, 1.0, 1]
# https://www.johnsonoutdoors.com/ johnson outdoors
# http://www.johnsonoutdoors.com/ johnson outdoors
#
# ['http://www.wikidata.org/entity/Q333718', '2433', 0.76, 1.0, 0]
# https://www.jnjconsumer.com.ua/ johnson & johnson
# http://www.jnj.com/ johnson & johnson
#
# ['http://www.wikidata.org/entity/Q71592934', '882', 0.7712, 0.92, 0.3]
#  koret
# http://www.kore1.com/ kore1
#
# ['http://www.wikidata.org/entity/Q153417', '262', 0.76, 1.0, 0]
# http://www.kroger.com/ kroger
# http://www.thekrogerco.com/ kroger
#
# ['http://www.wikidata.org/entity/Q1721601', '175', 1.0, 1.0, 1]
# ...
#  select media llc
# http://careers.selectmedical.com/ select medical
#
# ['http://www.wikidata.org/entity/Q7455653', '2437', 1.0, 1.0, 1]
# https://www.servicenow.com/ servicenow
# http://www.servicenow.com/ servicenow
#
# ['http://www.wikidata.org/entity/Q11306218', '1449', 1.0, 1.0, 1]
# https://www.sci-corp.com/ service corporation international
# http://www.sci-corp.com/ service corporation international
#
# ['http://www.wikidata.org/entity/Q7455674', '1449', 0.7677986013986015, 0.9155244755244756, 0.3]
#  service corporation of america
# http://www.sci-corp.com/ service corporation international
#
# ['http://www.wikidata.org/entity/Q7492551', '539', 0.76, 1.0, 0]
# http://www.sheetz.com/ sheetz
# http://www.jobs.sheetz.com/ sheetz
#
# ['http://www.wikidata.org/entity/Q48881', '2187', 1.0, 1.0, 1]
# https://www.sherwin-williams.com/ sherwin-williams
# http://www.sherwin-williams.com/ sherwin-williams
#
# ['http://www.wikidata.org/entity/Q3277465', '801', 0.983111111111111, 0.9777777777777777, 1]
# https://www.siriusxm.com/ sirius xm
# http://www.siriusxm.com/ siriusxm
#
# ['http://www.wikidata.org/entity/Q7538146', '1561', 0.962, 0.95, 1]
# http://www.skyworksinc.com/ skyworks solutions
# http://www.skyworksinc.com/ skyworks solutions, inc.
#
# ['http://www.wikidata.org/entity/Q17082162', '297', 0.76, 1.0, 0]
# http://sojern.com/ sojern
# https://sojern.cc/3QRzUfX/ sojern
#
# ['http://www.wikidata.org/entity/Q56826443', '638', 0.8016, 0.96, 0.3]
#  sony music entertainment, inc.
# http://www.sonymusic.com/ sony music entertainment
#
# ['http://www.wikidata.org/entity/Q7562151', '210', 1.0, 1.0, 1]
# http://www.sonoco.com/ sonoco
# http://www.sonoco.com/ sonoco
#
# ['http://www.wikidata.org/entity/Q3492619', '2559', 0.9170909090909092, 0.890909090909091, 1]
# http://www.sonos.com/ sonos
# http://www.sonos.com/ sonos, inc.
#
# ['http://www.wikidata.org/entity/Q2065128', '2406', 0.8863902894491129, 0.8505135387488328, 1]
# https://www.sonypictures.com/ sony pictures motion picture group
# http://www.sonypictures.com/ sony pictures entertainment
#
# ['http://www.wikidata.org/entity/Q97652952', '638', 0.7785945945945945, 0.9297297297297297, 0.3]
#  sony music entertainment us latin llc
# http://www.sonymusic.com/ sony music entertainment
#
# ['http://www.wikidata.org/entity/Q7562510', '2406', 0.7600814814814815, 0.9053703703703704, 0.3]
#  sony pictures family entertainment group
# http://www.sonypictures.com/ sony pictures entertainment
#
# ['http://www.wikidata.org/entity/Q7567571', '203', 1.0, 1.0, 1]
# http://www.sjindustries.com/ south jersey industries
# http://www.sjindustries.com/ south jersey industries
#
# ['http://www.wikidata.org/entity/Q7569789', '1975', 0.94528, 0.928, 1]
# http://www.southerncompany.com/ southern company services
# http://www.southerncompany.com/ southern company
#
# ['http://www.wikidata.org/entity/Q2304693', '1975', 1.0, 1.0, 1]
# http://www.southerncompany.com/ southern company
# http://www.southerncompany.com/ southern company
#
# ['http://www.wikidata.org/entity/Q7573760', '236', 0.76, 1.0, 0]
# http://www.sparrow.org/ sparrow health system
# http://sparrow.org/ sparrow health system
#
# ['http://www.wikidata.org/entity/Q30269302', '207', 0.9156442577030812, 0.8890056022408963, 1]
# http://www.sparktx.com/ spark therapeutics (united states)
# http://www.sparktx.com/ spark therapeutics, inc.
#
# ['http://www.wikidata.org/entity/Q3973275', '2517', 0.7632380952380952, 0.9095238095238095, 0.3]
#  stern's
# https://www.steris.com/ steris
#
# ['http://www.wikidata.org/entity/Q28458695', '70', 0.7813333333333333, 0.9333333333333333, 0.3]
#  storms
# http://www.storm3.com/ storm3
#
# ['http://www.wikidata.org/entity/Q645525', '648', 0.9088, 0.88, 1]
# https://us.sunpower.com/ sunpower
# http://us.sunpower.com/ sunpower corporation
#
# ['http://www.wikidata.org/entity/Q7655817', '745', 0.9430000000000001, 0.925, 1]
# http://www.sweetwater.com/ sweetwater sound
# http://www.sweetwater.com/ sweetwater
#
# ['http://www.wikidata.org/entity/Q107519426', '1501', 0.8986666666666666, 0.8666666666666666, 1]
# http://www.swissre.com/ swiss re (united states)
# http://www.swissre.com/ swiss re
#
# ['http://www.wikidata.org/entity/Q2376711', '1323', 1.0, 1.0, 1]
# http://www.sysco.com/ sysco
# http://www.sysco.com/ sysco
#
# ['http://www.wikidata.org/entity/Q7663559', '1942', 0.7864, 0.9400000000000001, 0.3]
#  syska hennessy
# http://www.syska.com/ syska hennessy group
#
# ['http://www.wikidata.org/entity/Q22121872', '479', 0.9649230769230769, 0.9538461538461538, 1]
# http://www.tandemdiabetes.com/ tandem diabetes care, inc.
# http://www.tandemdiabetes.com/ tandem diabetes care
#
# ['http://www.wikidata.org/entity/Q30289127', '479', 0.7644444444444444, 0.9111111111111111, 0.3]
#  tandem diabetes care (united states)
# http://www.tandemdiabetes.com/ tandem diabetes care
#
# ['http://www.wikidata.org/entity/Q7684751', '2007', 0.832, 1.0, 0.3]
#  tappan
# http://www.tappancollective.com/ tappan
#
# ['http://www.wikidata.org/entity/Q109612406', '2528', 1.0, 1.0, 1]
# https://www.tcgplayer.com/ tcgplayer
# http://www.tcgplayer.com/ tcgplayer
#
# ['http://www.wikidata.org/entity/Q740999', '2384', 0.76, 1.0, 0]
# http://www.tiaa-cref.org/ tiaa
# https://www.tiaa.org/ tiaa
#
# ['http://www.wikidata.org/entity/Q15109925', '2001', 1.0, 1.0, 1]
# http://www.tractorsupply.com/ tractor supply company
# http://www.tractorsupply.com/ tractor supply company
#
# ['http://www.wikidata.org/entity/Q1567477', '2360', 0.924, 0.9, 1]
# http://www.transamerica.com/ transamerica corporation
# http://www.transamerica.com/ transamerica
#
# ['http://www.wikidata.org/entity/Q18754966', '1682', 0.9493333333333334, 0.9333333333333333, 1]
# https://www.tradeweb.com/ tradeweb llc
# http://www.tradeweb.com/ tradeweb
#
# ['http://www.wikidata.org/entity/Q2297063', '1440', 0.9366666666666668, 0.9166666666666667, 1]
# http://www.trimble.com/ trimble
# http://www.trimble.com/ trimble inc.
#
# ['http://www.wikidata.org/entity/Q795486', '1702', 0.905, 0.875, 1]
# https://www.truist.com/ truist financial
# http://www.truist.com/ truist
#
# ['http://www.wikidata.org/entity/Q7671948', '2468', 1.0, 1.0, 1]
# http://www.tti.com/ tti, inc.
# https://www.tti.com/ tti, inc.
#
# ['http://www.wikidata.org/entity/Q1347679', '1812', 1.0, 1.0, 1]
# http://www.tek.com/ tektronix
# https://www.tek.com/ tektronix
#
# ['http://www.wikidata.org/entity/Q7696127', '1815', 0.9418823529411765, 0.9235294117647059, 1]
# http://www.teledyne.com/ teledyne technologies
# http://www.teledyne.com/ teledyne technologies incorporated
#
# ['http://www.wikidata.org/entity/Q1367577', '865', 1.0, 1.0, 1]
# http://www.tva.gov/ tennessee valley authority
# http://www.tva.gov/ tennessee valley authority
#
# ['http://www.wikidata.org/entity/Q1509038', '899', 1.0, 1.0, 1]
# http://www.tenneco.com/ tenneco
# http://www.tenneco.com/ tenneco
#
# ['http://www.wikidata.org/entity/Q7703033', '2106', 0.832, 1.0, 0.3]
#  terracycle
# http://www.terracycle.com/ terracycle
#
# ['http://www.wikidata.org/entity/Q7706196', '1830', 1.0, 1.0, 1]
# http://www.tetratech.com/ tetra tech
# http://www.tetratech.com/ tetra tech
#
# ['http://www.wikidata.org/entity/Q7720649', '1564', 0.784185994397759, 0.9370868347338935, 0.3]
#  the burke group
# http://www.theksquaregroup.com/ the ksquare group
#
# ['http://www.wikidata.org/entity/Q444110', '355', 1.0, 1.0, 1]
# http://www.thehartford.com/ the hartford
# https://www.thehartford.com/ the hartford
#
# ['http://www.wikidata.org/entity/Q7764745', '184', 0.7920095238095237, 0.9473809523809523, 0.3]
#  the slate group
# http://www.theplanetgroup.com/ the planet group
#
# ['http://www.wikidata.org/entity/Q7764745', '1394', 0.7920095238095237, 0.9473809523809523, 0.3]
#  the slate group
# https://www.selectgroup.com/ the select group
#
# ['http://www.wikidata.org/entity/Q7764745', '826', 0.7787999999999999, 0.9299999999999999, 0.3]
#  the slate group
# http://www.TheHTGroup.com/ the ht group
#
# ['http://www.wikidata.org/entity/Q7764745', '2025', 0.7759686274509804, 0.9262745098039216, 0.3]
#  the slate group
# http://www.kinsley-group.com/ the kinsley group
#
# ['http://www.wikidata.org/entity/Q7764745', '1906', 0.7680820512820512, 0.9158974358974359, 0.3]
#  the slate group
# http://www.qtigroup.com/ the qti group
#
# ['http://www.wikidata.org/entity/Q643674', '2459', 1.0, 1.0, 1]
# http://www.thermofisher.com/ thermo fisher scientific
# https://www.thermofisher.com/ thermo fisher scientific
#
# ['http://www.wikidata.org/entity/Q18331834', '845', 0.7674, 0.915, 0.3]
#  the owl drug company
# http://www.TheStowCompany.com/ the stow company
#
# ['http://www.wikidata.org/entity/Q7743510', '184', 0.7636, 0.91, 0.3]
#  the jones group
# http://www.theplanetgroup.com/ the planet group
#
# ['http://www.wikidata.org/entity/Q7743510', '2025', 0.7642763197586726, 0.9108898944193061, 0.3]
#  the jones group
# http://www.kinsley-group.com/ the kinsley group
#
# ['http://www.wikidata.org/entity/Q7746584', '184', 0.7753193277310925, 0.9254201680672269, 0.3]
#  the leavitt group
# http://www.theplanetgroup.com/ the planet group
#
# ['http://www.wikidata.org/entity/Q7746584', '826', 0.7656862745098039, 0.9127450980392157, 0.3]
#  the leavitt group
# http://www.TheHTGroup.com/ the ht group
#
# ['http://www.wikidata.org/entity/Q7746584', '1906', 0.7629351432880844, 0.9091251885369532, 0.3]
#  the leavitt group
# http://www.qtigroup.com/ the qti group
#
# ['http://www.wikidata.org/entity/Q7940496', '583', 0.832, 1.0, 0.3]
#  the vollrath company
# http://www.vollrathcompany.com/ the vollrath company
#
# ['http://www.wikidata.org/entity/Q864407', '2434', 0.76, 1.0, 0]
# https://www.homedepot.com/ the home depot
# http://www.careers.homedepot.com/ the home depot
#
# ['http://www.wikidata.org/entity/Q3520257', '619', 1.0, 1.0, 1]
# https://www.childrensplace.com/ the children's place
# http://www.childrensplace.com/ the children's place
#
# ['http://www.wikidata.org/entity/Q7738596', '845', 0.7832333333333333, 0.9358333333333334, 0.3]
#  the hon company
# http://www.TheStowCompany.com/ the stow company
#
# ['http://www.wikidata.org/entity/Q7761625', '845', 0.7753193277310925, 0.9254201680672269, 0.3]
#  the rouse company
# http://www.TheStowCompany.com/ the stow company
#
# ['http://www.wikidata.org/entity/Q7755673', '845', 0.7683650793650793, 0.9162698412698412, 0.3]
#  the outlet company
# http://www.TheStowCompany.com/ the stow company
#
# ['http://www.wikidata.org/entity/Q7414', '2260', 0.76, 1.0, 0]
# https://www.disney.co.uk/ the walt disney company
# http://www.disneycareers.com/ the walt disney company
#
# ['http://www.wikidata.org/entity/Q64142786', '843', 0.9376410256410257, 0.917948717948718, 1]
# http://www.pole3.com/ third pole therapeutics (united states)
# http://www.pole3.com/ third pole therapeutics
#
# ['http://www.wikidata.org/entity/Q7802889', '2180', 1.0, 1.0, 1]
# http://www.tillys.com/ tillys
# http://www.tillys.com/ tillys
#
# ['http://www.wikidata.org/entity/Q1359692', '2054', 0.76, 1.0, 0]
# https://tishmanspeyer.com/ tishman speyer
# http://www.tishmanspeyer.com/ tishman speyer
#
# ['http://www.wikidata.org/entity/Q7827120', '1068', 1.0, 1.0, 1]
# http://www.torrid.com/ torrid
# https://www.torrid.com/ torrid
#
# ['http://www.wikidata.org/entity/Q7310889', '791', 0.76, 1.0, 0]
# https://turo.com/gb/en/ turo
# https://turo.com/ turo
#
# ['http://www.wikidata.org/entity/Q7856969', '318', 1.0, 1.0, 1]
# http://www.Tutor.com/ tutor.com
# http://www.tutor.com/ tutor.com
#
# ['http://www.wikidata.org/entity/Q1325987', '1372', 0.76, 1.0, 0]
# http://www.tyson.com/ tyson foods
# http://tysonfoods.com/ tyson foods
#
# ['http://www.wikidata.org/entity/Q7880076', '602', 1.0, 1.0, 1]
# https://www.ulta.com/ ulta beauty
# https://www.ulta.com/ ulta beauty
#
# ['http://www.wikidata.org/entity/Q7894018', '535', 0.7606666666666667, 0.906140350877193, 0.3]
#  universal music distribution
# http://www.universalmusic.com/ universal music group
#
# ['http://www.wikidata.org/entity/Q1442600', '2189', 0.8704695652173914, 0.8295652173913044, 1]
# http://www.unionbank.com/ unionbancal corporation
# https://www.unionbank.com/ union bank
#
# ['http://www.wikidata.org/entity/Q7865722', '2633', 0.76, 1.0, 0]
# https://www.usaa.com/ usaa
# http://www.usaajobs.com/ usaa
#
# ['http://www.wikidata.org/entity/Q780442', '2358', 0.8885333333333333, 0.8533333333333333, 1]
# https://www.uber.com/ uber technology
# http://www.uber.com/ uber
#
# ['http://www.wikidata.org/entity/Q7879030', '1720', 1.0, 1.0, 1]
# https://www.uline.com/ uline
# http://www.uline.com/ uline
#
# ['http://www.wikidata.org/entity/Q3344170', '1471', 1.0, 1.0, 1]
# https://www.upwork.com/ upwork
# https://www.upwork.com/ upwork
#
# ['http://www.wikidata.org/entity/Q1283291', '114', 0.88448, 0.8480000000000001, 1]
# https://www.valero.com/ valero energy corporation
# http://www.valero.com/ valero
#
# ['http://www.wikidata.org/entity/Q332477', '86', 0.76, 1.0, 0]
# https://www.victoriassecret.com/ victoria's secret
# http://careers.victoriassecret.com/ victoria's secret
#
# ['http://www.wikidata.org/entity/Q7907025', '579', 0.9746666666666667, 0.9666666666666667, 1]
# http://www.Vince.com/ vince.
# http://www.vince.com/ vince
#
# ['http://www.wikidata.org/entity/Q2516971', '1572', 1.0, 1.0, 1]
# http://www.virtusa.com/ virtusa
# http://www.virtusa.com/ virtusa
#
# ['http://www.wikidata.org/entity/Q19604609', '655', 0.8066666666666666, 0.9666666666666667, 0.3]
#  vericel
# https://vercel.com/ vercel
#
# ['http://www.wikidata.org/entity/Q3561692', '400', 1.0, 1.0, 1]
# http://www.vizio.com/ vizio
# http://www.VIZIO.com/ vizio
#
# ['http://www.wikidata.org/entity/Q744149', '2598', 1.0, 1.0, 1]
# https://www.wellsfargo.com/ wells fargo
# http://www.wellsfargo.com/ wells fargo
#
# ['http://www.wikidata.org/entity/Q632404', '915', 0.7938808777429467, 0.9498432601880877, 0.3]
#  westinghouse electric corporation
# http://www.westinghousenuclear.com/ westinghouse electric company
#
# ['http://www.wikidata.org/entity/Q7949044', '2102', 0.888, 0.8526315789473684, 1]
# http://www.wesco.com/ wesco international
# http://www.wesco.com/ wesco
#
# ['http://www.wikidata.org/entity/Q1133735', '915', 1.0, 1.0, 1]
# http://www.westinghousenuclear.com/ westinghouse electric company
# http://www.westinghousenuclear.com/ westinghouse electric company
#
# ['http://www.wikidata.org/entity/Q16912277', '1246', 0.76, 1.0, 0]
# http://www.wsp-pb.com/ wsp usa
# http://www.wsp.com/ wsp usa
#
# ['http://www.wikidata.org/entity/Q191715', '2447', 1.0, 1.0, 1]
# https://www.warnermedia.com/ warnermedia
# https://www.warnermedia.com/ warnermedia
#
# ['http://www.wikidata.org/entity/Q483551', '2580', 0.76, 1.0, 0]
# https://www.walmart.com/ walmart
# https://bit.ly/3IBowlZ/ walmart
#
# ['http://www.wikidata.org/entity/Q7977212', '1625', 0.76, 1.0, 0]
# https://go.wepay.com/ wepay
# https://wepay.com/ wepay
#
# ['http://www.wikidata.org/entity/Q17183565', '1254', 1.0, 1.0, 1]
# https://www.webstaurantstore.com/ webstaurantstore
# https://www.webstaurantstore.com/ webstaurantstore
#
# ['http://www.wikidata.org/entity/Q7980178', '350', 0.9766153846153847, 0.9692307692307692, 1]
# http://www.weil.com/ weil, gotshal & manges
# http://www.weil.com/ weil, gotshal & manges llp
#
# ['http://www.wikidata.org/entity/Q1809448', '2204', 0.76, 1.0, 0]
# https://www.wholefoodsmarket.com/ whole foods market
# http://www.wholefoodsmarket.com/careers/ whole foods market
#
# ['http://www.wikidata.org/entity/Q8022892', '1551', 0.912, 0.8842105263157894, 1]
# http://www.wilshire.com/ wilshire associates
# http://www.wilshire.com/ wilshire
#
# ['http://www.wikidata.org/entity/Q8034666', '2226', 0.9298461538461539, 0.9076923076923077, 1]
# https://www.workday.com/ workday, inc.
# http://www.workday.com/ workday
#
# ['http://www.wikidata.org/entity/Q29231846', '2228', 0.924, 0.9, 1]
# https://www.yahooinc.com/ yahoo inc.
# http://www.yahooinc.com/ yahoo
#
# ['http://www.wikidata.org/entity/Q205378', '1353', 1.0, 1.0, 1]
# http://www.zionsbancorporation.com/ zions bancorporation
# http://www.zionsbancorporation.com/ zions bancorporation
#
# ['http://www.wikidata.org/entity/Q30298750', '1339', 0.90595, 0.8762500000000001, 1]
# http://www.zeltech.com/ zel technologies (united states)
# http://www.zeltech.com/ zel technologies llc
#
# ['http://www.wikidata.org/entity/Q16968488', '812', 0.76, 1.0, 0]
# http://www.zulily.com/ zulily
# http://www.zulily.com/careers/ zulily

# %%
# deduplicate
matchPairs_wl1 = {}
# depulicate wikidata id:
for ids in matchPairs_wl:
    if ids[0] not in matchPairs_wl1:
        matchPairs_wl1[ids[0]] = []
    matchPairs_wl1[ids[0]].append(ids)
for i in matchPairs_wl1:
    if len(matchPairs_wl1[i]) > 1:
        best = max(matchPairs_wl1[i], key=lambda x: x[2])
        matchPairs_wl1[i] = best
    else:
        matchPairs_wl1[i] = matchPairs_wl1[i][0]

# depulicate glassdoor id:
matchPairs_wl2 = {}
for ids in matchPairs_wl1.values():
    if ids[1] not in matchPairs_wl2:
        matchPairs_wl2[ids[1]] = []
    matchPairs_wl2[ids[1]].append(ids)

for i in matchPairs_wl2:
    if len(matchPairs_wl2[i]) > 1:
        best = max(matchPairs_wl2[i], key=lambda x: x[2])
        matchPairs_wl2[i] = best
    else:
        matchPairs_wl2[i] = matchPairs_wl2[i][0]
matchPairs_wl_deduplicate = list(matchPairs_wl2.values())
len(matchPairs_wl_deduplicate)
# Out:
# 515

# %%
with open(dir_ + 'linkage/w_l_linkage.csv', mode='w') as file:
    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(["wikidata.id", "linkedin.id"])
    for row in matchPairs_wl_deduplicate:
        writer.writerow((row[0], row[1]))

# %% [markdown]
# ### blocking linkedin-wikidata

# %%
bg3 = rltk.HashBlockGenerator()

block3 = bg3.generate(
    bg3.block(ds_wikidata, property_="first3title"),
    bg3.block(ds_glassdoor, property_="first3title")
)

# %%
matchPairs_wg = []
for r_wikidata, r_glassdoor in rltk.get_record_pairs(ds_wikidata, ds_glassdoor, block=block3):
    result, confidence, score_1, score_2 = rule_based_method2(r_wikidata, r_glassdoor)
    if result == True:
        matchPairs_wg.append([r_wikidata.id, r_glassdoor.id, confidence, score_1, score_2])

# %%
len(matchPairs_wg)
# Out:
# 163

# %%
for ids in matchPairs_wg:
    print(ids)
    r_wikidata = ds_wikidata.get_record(ids[0])
    r_glassdoor = ds_glassdoor.get_record(ids[1])
    print(r_wikidata.website_string, r_wikidata.name_string)
    print(r_glassdoor.website_string, r_glassdoor.name_string, "\n")
# Out:
# ['http://www.wikidata.org/entity/Q4652197', '482', 0.8098333333333333, 0.9708333333333333, 0.3]
#  aks inc
# http://www.aksincorporated.com/ aks, inc
#
# ['http://www.wikidata.org/entity/Q4733393', '129', 0.8685079365079365, 0.8269841269841269, 1]
# http://www.ally.com/ ally bank
# http://www.ally.com/ ally financial
#
# ['http://www.wikidata.org/entity/Q2032800', '129', 1.0, 1.0, 1]
# https://www.ally.com/ ally financial
# http://www.ally.com/ ally financial
#
# ['http://www.wikidata.org/entity/Q2645636', '127', 1.0, 1.0, 1]
# https://www.allstate.com/ allstate
# http://www.allstate.com/ allstate
#
# ['http://www.wikidata.org/entity/Q344839', '456', 0.76, 1.0, 0]
# http://www.acushnet.com/ acushnet company
# http://www.acushnetholdingscorp.com/ acushnet company
#
# ['http://www.wikidata.org/entity/Q11463', '46', 1.0, 1.0, 1]
# https://www.adobe.com/ adobe
# http://www.adobe.com/ adobe
#
# ['http://www.wikidata.org/entity/Q30338375', '330', 0.8841904761904762, 0.8476190476190476, 1]
# http://www.aecom.com/ aecom (united states)
# http://www.aecom.com/ aecom
#
# ['http://www.wikidata.org/entity/Q470517', '639', 1.0, 1.0, 1]
# http://www.amgen.com/ amgen
# http://www.amgen.com/ amgen
#
# ['http://www.wikidata.org/entity/Q484930', '52', 1.0, 1.0, 1]
# https://www.analog.com/ analog devices
# http://www.analog.com/ analog devices
#
# ['http://www.wikidata.org/entity/Q4781354', '40', 0.7885714285714285, 0.9428571428571428, 0.3]
#  applera
# http://www.apple.com/ apple
#
# ['http://www.wikidata.org/entity/Q312', '40', 1.0, 1.0, 1]
# https://www.apple.com/ apple
# http://www.apple.com/ apple
#
# ['http://www.wikidata.org/entity/Q4796291', '847', 0.7610666666666667, 0.9066666666666667, 0.3]
#  arryx
# http://www.array.com/ array
#
# ['http://www.wikidata.org/entity/Q113988065', '847', 0.76, 1.0, 0]
# https://array.com/ array
# http://www.array.com/ array
#
# ['http://www.wikidata.org/entity/Q27978540', '142', 0.76, 1.0, 0]
# https://www.bridgestoneamericas.com/en/index.html/ bridgestone americas
# http://www.bridgestoneamericas.com/ bridgestone americas
#
# ['http://www.wikidata.org/entity/Q266423', '176', 0.9608, 0.9484210526315789, 1]
# https://www.bms.com/ bristol-myers squibb
# http://www.bms.com/ bristol myers squibb
#
# ['http://www.wikidata.org/entity/Q4855887', '574', 1.0, 1.0, 1]
# http://www.bankunited.com/ bankunited
# http://www.bankunited.com/ bankunited
#
# ['http://www.wikidata.org/entity/Q761965', '731', 0.8936, 0.86, 1]
# http://www.baxter.com/ baxter international
# http://www.baxter.com/ baxter
#
# ['http://www.wikidata.org/entity/Q29526078', '139', 1.0, 1.0, 1]
# http://www.bloomenergy.com/ bloom energy
# http://www.bloomenergy.com/ bloom energy
#
# ['http://www.wikidata.org/entity/Q66', '732', 1.0, 1.0, 1]
# https://www.boeing.com/ boeing
# http://www.boeing.com/ boeing
#
# ['http://www.wikidata.org/entity/Q893221', '657', 1.0, 1.0, 1]
# http://www.boozallen.com/ booz allen hamilton
# http://www.boozallen.com/ booz allen hamilton
#
# ['http://www.wikidata.org/entity/Q135635', '125', 1.0, 1.0, 1]
# https://www.bcg.com/ boston consulting group
# http://www.bcg.com/ boston consulting group
#
# ['http://www.wikidata.org/entity/Q5025548', '578', 0.7982222222222222, 0.9555555555555556, 0.3]
#  cambridge systematics
# http://www.camsys.com/ cambridge systematics, inc.
#
# ['http://www.wikidata.org/entity/Q1045890', '335', 0.7596190476190476, 0.9047619047619048, 0.3]
#  cartercar
# http://www.careers.cartier.com/ cartier
#
# ['http://www.wikidata.org/entity/Q459965', '69', 0.9525, 0.9375, 1]
# https://www.caterpillar.com/ caterpillar inc.
# http://www.caterpillar.com/ caterpillar
#
# ['http://www.wikidata.org/entity/Q23018218', '487', 1.0, 1.0, 1]
# http://www.cdmsmith.com/ cdm smith
# https://www.cdmsmith.com/ cdm smith
#
# ['http://www.wikidata.org/entity/Q93355376', '592', 0.8733333333333334, 0.8333333333333334, 1]
# https://www.citigroup.com/ citigroup global markets
# http://www.citigroup.com/ citi
#
# ['http://www.wikidata.org/entity/Q219508', '592', 0.9155555555555556, 0.888888888888889, 1]
# http://www.citigroup.com/ citigroup
# http://www.citigroup.com/ citi
#
# ['http://www.wikidata.org/entity/Q1107035', '665', 1.0, 1.0, 1]
# https://www.cognizant.com/ cognizant
# http://www.cognizant.com/ cognizant
#
# ['http://www.wikidata.org/entity/Q1113804', '58', 0.76, 1.0, 0]
# https://www.cmcsa.com/ comcast
# http://www.comcastcareers.com/ comcast
#
# ['http://www.wikidata.org/entity/Q5153675', '495', 0.7813333333333333, 0.9333333333333333, 0.3]
#  commonwealth
# http://www.employment.pa.gov/ commonwealth of pa
#
# ['http://www.wikidata.org/entity/Q30297920', '423', 0.9150310559006212, 0.8881987577639752, 1]
# http://www.corvidtec.com/ corvid technologies (united states)
# http://www.corvidtec.com/ corvid technologies llc
#
# ['http://www.wikidata.org/entity/Q23016736', '95', 1.0, 1.0, 1]
# http://www.cybercoders.com/ cybercoders
# http://www.cybercoders.com/ cybercoders
#
# ['http://www.wikidata.org/entity/Q5197770', '95', 0.7598383838383838, 0.905050505050505, 0.3]
#  cyberdreams
# http://www.cybercoders.com/ cybercoders
#
# ['http://www.wikidata.org/entity/Q1034654', '317', 0.76, 1.0, 0]
# https://www.capitalone.com/ capital one
# http://www.capitalonecareers.com/ capital one
#
# ['http://www.wikidata.org/entity/Q609466', '904', 0.9513600000000001, 0.936, 1]
# http://www.colgatepalmolive.com/ colgate-palmolive company
# http://www.colgatepalmolive.com/ colgate-palmolive
#
# ['http://www.wikidata.org/entity/Q1112588', '173', 0.76, 1.0, 0]
# https://www.columbia.com/ columbia sportswear company
# http://www.columbiasportswearcompany.com/ columbia sportswear company
#
# ['http://www.wikidata.org/entity/Q5166543', '937', 0.7632380952380952, 0.9095238095238095, 0.3]
#  convia
# http://corporate.westernunion.com/ convera
#
# ['http://www.wikidata.org/entity/Q5165246', '101', 0.7655082373343243, 0.9125108385977951, 0.3]
#  continental baking company
# http://www.continentalfinance.net/ continental finance company
#
# ['http://www.wikidata.org/entity/Q1228575', '685', 0.7668571428571428, 0.9142857142857143, 0.3]
#  discovery toys
# http://jobs.discover.com/ discover
#
# ['http://www.wikidata.org/entity/Q5281990', '685', 0.7668571428571428, 0.9142857142857143, 0.3]
#  discovery zone
# http://jobs.discover.com/ discover
#
# ['http://www.wikidata.org/entity/Q5272601', '921', 0.76, 1.0, 0]
# https://www.dickssportinggoods.com/ dick's sporting goods
# http://www.dickssportinggoods.jobs/ dick's sporting goods
#
# ['http://www.wikidata.org/entity/Q677464', '413', 1.0, 1.0, 1]
# https://www.dominionenergy.com/ dominion energy
# http://www.dominionenergy.com/ dominion energy
#
# ['http://www.wikidata.org/entity/Q1126244', '12', 0.92, 0.8947368421052632, 1]
# https://www.dowjones.com/ dow jones & company
# http://www.dowjones.com/ dow jones
#
# ['http://www.wikidata.org/entity/Q64187080', '16', 1.0, 1.0, 1]
# http://www.drivenbrands.com/ driven brands
# http://www.drivenbrands.com/ driven brands
#
# ['http://www.wikidata.org/entity/Q15589464', '550', 0.9366666666666668, 0.9166666666666667, 1]
# http://www.dropbox.com/ dropbox inc.
# http://www.dropbox.com/ dropbox
#
# ['http://www.wikidata.org/entity/Q16992684', '183', 0.9848, 0.98, 1]
# http://www.eplus.com/ eplus inc
# http://www.eplus.com/ eplus inc.
#
# ['http://www.wikidata.org/entity/Q64141604', '765', 0.9341812612612613, 0.9133963963963965, 1]
# https://www.exptechinc.com/ expedition technology (united states)
# http://www.exptechinc.com/ expedition technology inc
#
# ['http://www.wikidata.org/entity/Q677488', '124', 0.9565714285714285, 0.9428571428571428, 1]
# https://www.elevancehealth.com/ elevance health, inc.
# http://www.elevancehealth.com/ elevance health
#
# ['http://www.wikidata.org/entity/Q3029296', '79', 1.0, 1.0, 1]
# https://www.f5.com/ f5
# http://www.f5.com/ f5
#
# ['http://www.wikidata.org/entity/Q1411292', '559', 0.76, 1.0, 0]
# https://www.fidelity.com/ fidelity investments
# http://www.fidelitycareers.com/ fidelity investments
#
# ['http://www.wikidata.org/entity/Q3072937', '605', 1.0, 1.0, 1]
# http://www.fhb.com/ first hawaiian bank
# http://www.fhb.com/ first hawaiian bank
#
# ['http://www.wikidata.org/entity/Q5452290', '26', 0.9343931623931625, 0.9136752136752138, 1]
# http://www.firstam.com/ first american corporation
# http://www.firstam.com/ first american financial corporation
#
# ['http://www.wikidata.org/entity/Q44294', '158', 0.76, 1.0, 0]
# http://www.ford.com/ ford motor company
# http://corporate.ford.com/careers/ ford motor company
#
# ['http://www.wikidata.org/entity/Q935969', '686', 0.76, 1.0, 0]
# http://www.freddiemac.com/ freddie mac
# http://careers.freddiemac.com/ freddie mac
#
# ['http://www.wikidata.org/entity/Q2974454', '74', 0.76, 1.0, 0]
# https://frontier.com/ frontier communications
# http://www.frontier.com/careers/ frontier communications
#
# ['http://www.wikidata.org/entity/Q5505970', '74', 0.7828235294117647, 0.9352941176470588, 0.3]
#  frontier communications west coast
# http://www.frontier.com/careers/ frontier communications
#
# ['http://www.wikidata.org/entity/Q16993862', '617', 1.0, 1.0, 1]
# http://www.fuelcellenergy.com/ fuelcell energy
# http://www.fuelcellenergy.com/ fuelcell energy
#
# ['http://www.wikidata.org/entity/Q30256711', '473', 0.9680000000000001, 0.9578947368421054, 1]
# http://www.geiconsultants.com/ gei consultants
# http://www.geiconsultants.com/ gei consultants inc
#
# ['http://www.wikidata.org/entity/Q1498689', '711', 0.76, 1.0, 0]
# https://www.geico.com/ geico
# http://www.geico.careers/ geico
#
# ['http://www.wikidata.org/entity/Q5533186', '544', 0.8955000000000001, 0.8625, 1]
# http://www.genielift.com/ genie industries
# http://www.genielift.com/ genie
#
# ['http://www.wikidata.org/entity/Q5513853', '560', 0.76, 1.0, 0]
# https://www.gmfinancial.com/en-us/home.html/ gm financial
# http://www.gmfinancial.com/ gm financial
#
# ['http://www.wikidata.org/entity/Q2470307', '163', 0.9113333333333334, 0.8833333333333334, 1]
# http://www.guess.com/ guess
# http://www.guess.com/ guess?. inc.
#
# ['http://www.wikidata.org/entity/Q5712288', '518', 0.7681059979101358, 0.9159289446185997, 0.3]
#  hemlock semiconductor corporation
# http://www.hscpoly.com/ hemlock semiconductor ops llc
#
# ['http://www.wikidata.org/entity/Q13636126', '820', 0.76, 1.0, 0]
# https://www.hiltongrandvacations.com/ hilton grand vacations
# https://careers.hgv.com/ hilton grand vacations
#
# ['http://www.wikidata.org/entity/Q37156', '669', 1.0, 1.0, 1]
# https://www.ibm.com/ ibm
# http://www.ibm.com/ ibm
#
# ['http://www.wikidata.org/entity/Q1758392', '48', 0.8796666666666667, 0.8416666666666667, 1]
# http://www.idexx.com/ idexx laboratories, inc.
# http://www.idexx.com/ idexx
#
# ['http://www.wikidata.org/entity/Q30338410', '886', 0.7662702702702703, 0.9135135135135135, 0.3]
#  infineon technologies (united states)
# http://www.infineon.com/ infineon technologies
#
# ['http://www.wikidata.org/entity/Q6047563', '75', 0.76, 1.0, 0]
# https://intermountainhealthcare.org/ intermountain healthcare
# http://www.intermountainhealthcare.org/ intermountain healthcare
#
# ['http://www.wikidata.org/entity/Q3799482', '540', 0.7644444444444444, 0.9111111111111111, 0.3]
#  interleaf
# https://jobs.intel.com/ intel
#
# ['http://www.wikidata.org/entity/Q16919728', '540', 0.7644444444444444, 0.9111111111111111, 0.3]
#  interlink
# https://jobs.intel.com/ intel
#
# ['http://www.wikidata.org/entity/Q16919728', '562', 0.7596190476190476, 0.9047619047619048, 0.3]
#  interlink
# http://www.internu.com/ internu
#
# ['http://www.wikidata.org/entity/Q248', '540', 0.76, 1.0, 0]
# https://www.intel.com/ intel
# https://jobs.intel.com/ intel
#
# ['http://www.wikidata.org/entity/Q1538585', '377', 0.9022857142857142, 0.8714285714285714, 1]
# http://www.kellyservices.com/ kelly services
# http://www.kellyservices.com/ kelly
#
# ['http://www.wikidata.org/entity/Q6398722', '615', 1.0, 1.0, 1]
# https://www.kforce.com/ kforce
# https://www.kforce.com/ kforce
#
# ['http://www.wikidata.org/entity/Q1741634', '370', 1.0, 1.0, 1]
# http://www.kimberly-clark.com/ kimberly-clark
# http://www.kimberly-clark.com/ kimberly-clark
#
# ['http://www.wikidata.org/entity/Q486269', '763', 1.0, 1.0, 1]
# https://www.kodak.com/ kodak
# http://www.kodak.com/ kodak
#
# ['http://www.wikidata.org/entity/Q6535711', '749', 0.8986666666666666, 0.8666666666666666, 1]
# http://www.Leviton.com/ leviton
# http://www.leviton.com/ leviton manufacturing
#
# ['http://www.wikidata.org/entity/Q637440', '852', 0.9309090909090909, 0.9090909090909091, 1]
# http://www.lazard.com/ lazard
# http://www.lazard.com/ lazard ltd.
#
# ['http://www.wikidata.org/entity/Q502132', '265', 1.0, 1.0, 1]
# http://www.leidos.com/ leidos
# http://www.leidos.com/ leidos
#
# ['http://www.wikidata.org/entity/Q1516450', '25', 0.9366666666666668, 0.9166666666666667, 1]
# http://www.libertymutualgroup.com/ liberty mutual
# http://www.libertymutualgroup.com/ liberty mutual insurance
#
# ['http://www.wikidata.org/entity/Q17031875', '358', 1.0, 1.0, 1]
# https://www.liquidweb.com/ liquid web
# http://www.liquidweb.com/ liquid web
#
# ['http://www.wikidata.org/entity/Q7240', '530', 0.9324444444444444, 0.9111111111111111, 1]
# https://www.lockheedmartin.com/ lockheed martin
# http://www.lockheedmartin.com/ lockheed martin corporation
#
# ['http://www.wikidata.org/entity/Q23136174', '85', 1.0, 1.0, 1]
# http://www.lmi.org/ logistics management institute
# http://www.lmi.org/ logistics management institute
#
# ['http://www.wikidata.org/entity/Q5063092', '57', 0.8902222222222221, 0.8555555555555555, 1]
# https://www.lumen.com/ lumen technologies
# http://www.lumen.com/ lumen
#
# ['http://www.wikidata.org/entity/Q1130172', '649', 1.0, 1.0, 1]
# http://www.mayoclinic.org/ mayo clinic
# http://www.mayoclinic.org/ mayo clinic
#
# ['http://www.wikidata.org/entity/Q1916145', '899', 0.9702333333333333, 0.9608333333333333, 1]
# http://www.medianewsgroup.com/ medianews group
# http://www.medianewsgroup.com/ media news group
#
# ['http://www.wikidata.org/entity/Q24259377', '485', 0.7644444444444444, 0.9111111111111111, 0.3]
#  metro
# http://www.metromont.com/ metromont
#
# ['http://www.wikidata.org/entity/Q1949427', '108', 1.0, 1.0, 1]
# http://www.mossadams.com/ moss adams
# http://www.mossadams.com/ moss adams
#
# ['http://www.wikidata.org/entity/Q113466813', '220', 0.8790100334448161, 0.8408026755852843, 1]
# http://www.macquarie.com/ macquarie inc
# http://www.macquarie.com/ macquarie group limited
#
# ['http://www.wikidata.org/entity/Q570473', '582', 0.9088, 0.88, 1]
# http://www.mckesson.com/ mckesson corporation
# http://www.mckesson.com/ mckesson
#
# ['http://www.wikidata.org/entity/Q2283', '42', 0.76, 1.0, 0]
# https://www.microsoft.com/ microsoft
# https://www.microsoft.com/en-gb/ microsoft
#
# ['http://www.wikidata.org/entity/Q80055169', '42', 0.7655, 0.9125, 0.3]
#  microsoft online
# https://www.microsoft.com/en-gb/ microsoft
#
# ['http://www.wikidata.org/entity/Q6896175', '599', 0.76, 1.0, 0]
# http://molinahealthcare.com/ molina healthcare
# http://careers.molinahealthcare.com/ molina healthcare
#
# ['http://www.wikidata.org/entity/Q1943826', '766', 0.76, 1.0, 0]
# https://www.momentive.com/zh-cn/ momentive
# http://www.momentive.com/ momentive
#
# ['http://www.wikidata.org/entity/Q634815', '736', 1.0, 1.0, 1]
# https://www.motorolasolutions.com/ motorola solutions
# http://www.motorolasolutions.com/ motorola solutions
#
# ['http://www.wikidata.org/entity/Q1817417', '756', 1.0, 1.0, 1]
# http://www.nov.com/ national oilwell varco
# http://www.nov.com/ national oilwell varco
#
# ['http://www.wikidata.org/entity/Q6982632', '102', 1.0, 1.0, 1]
# https://www.navyfederal.org/ navy federal credit union
# http://www.navyfederal.org/ navy federal credit union
#
# ['http://www.wikidata.org/entity/Q727883', '542', 0.9045128205128206, 0.8743589743589745, 1]
# https://www.netapp.com/ netapp
# http://www.netapp.com/ net app, inc.
#
# ['http://www.wikidata.org/entity/Q329953', '97', 1.0, 1.0, 1]
# http://www.northropgrumman.com/ northrop grumman
# http://www.northropgrumman.com/ northrop grumman
#
# ['http://www.wikidata.org/entity/Q7095328', '372', 0.9155555555555556, 0.888888888888889, 1]
# http://www.ooma.com/ ooma
# http://www.ooma.com/ ooma, inc
#
# ['http://www.wikidata.org/entity/Q3896512', '417', 0.9039999999999999, 0.8736842105263157, 1]
# http://www.parsons.com/ parsons corporation
# http://www.parsons.com/ parsons
#
# ['http://www.wikidata.org/entity/Q255381', '933', 1.0, 1.0, 1]
# https://www.pinterest.com/ pinterest
# http://www.pinterest.com/ pinterest
#
# ['http://www.wikidata.org/entity/Q2044512', '72', 0.8581333333333333, 0.8133333333333334, 1]
# http://www.pplweb.com/ ppl
# http://www.pplweb.com/ ppl corporation
#
# ['http://www.wikidata.org/entity/Q212405', '374', 1.0, 1.0, 1]
# http://www.pg.com/ procter & gamble
# http://www.pg.com/ procter & gamble
#
# ['http://www.wikidata.org/entity/Q7248721', '227', 0.920695652173913, 0.8956521739130435, 1]
# https://www.progressive.com/ progressive corporation
# http://www.progressive.com/ progressive
#
# ['http://www.wikidata.org/entity/Q45137247', '374', 0.7594971014492753, 0.9046014492753623, 0.3]
#  procter and gamble fund
# http://www.pg.com/ procter & gamble
#
# ['http://www.wikidata.org/entity/Q483959', '50', 1.0, 1.0, 1]
# https://www.paypal.com/ paypal
# http://www.paypal.com/ paypal
#
# ['http://www.wikidata.org/entity/Q108443888', '60', 1.0, 1.0, 1]
# https://www.peraton.com/ peraton
# http://www.peraton.com/ peraton
#
# ['http://www.wikidata.org/entity/Q428977', '819', 0.76, 1.0, 0]
# http://www.pitneybowes.com/us/ pitney bowes
# http://www.pitneybowes.com/ pitney bowes
#
# ['http://www.wikidata.org/entity/Q3552628', '376', 0.76, 1.0, 0]
# https://www.raytheonmissilesanddefense.com/ raytheon missiles & defense
# http://www.f2ftalentsolutions.com/ raytheon missiles & defense
#
# ['http://www.wikidata.org/entity/Q105445643', '82', 1.0, 1.0, 1]
# https://www.renofi.com/ renofi
# http://www.renofi.com/ renofi
#
# ['http://www.wikidata.org/entity/Q65557889', '36', 0.7601454545454545, 0.9054545454545454, 0.3]
#  robertshaw
# http://www.roberthalf.com/ robert half
#
# ['http://www.wikidata.org/entity/Q30298449', '410', 0.924, 0.9, 1]
# https://www.roboticresearch.com/ robotic research (united states)
# http://www.roboticresearch.com/ robotic research
#
# ['http://www.wikidata.org/entity/Q2157448', '36', 1.0, 1.0, 1]
# http://www.roberthalf.com/ robert half
# http://www.roberthalf.com/ robert half
#
# ['http://www.wikidata.org/entity/Q7491173', '59', 0.7644444444444444, 0.9111111111111111, 0.3]
#  shaw industries
# http://www.shawinc.com/ shaw industries group, inc.
#
# ['http://www.wikidata.org/entity/Q110337159', '131', 1.0, 1.0, 1]
# https://www.simplifycompliance.com/ simplify compliance
# http://www.simplifycompliance.com/ simplify compliance
#
# ['http://www.wikidata.org/entity/Q85802558', '24', 0.7668571428571428, 0.9142857142857143, 0.3]
#  spectrum astro
# http://jobs.spectrum.com/ spectrum
#
# ['http://www.wikidata.org/entity/Q7805197', '24', 0.76, 1.0, 0]
# https://www.spectrum.com/ spectrum
# http://jobs.spectrum.com/ spectrum
#
# ['http://www.wikidata.org/entity/Q7575683', '475', 0.9493333333333334, 0.9333333333333333, 1]
# https://www.speedway.com/ speedway
# http://www.speedway.com/ speedway llc
#
# ['http://www.wikidata.org/entity/Q37158', '862', 0.76, 1.0, 0]
# https://www.starbucks.com/ starbucks
# http://www.starbucks.com/careers/ starbucks
#
# ['http://www.wikidata.org/entity/Q7399844', '115', 0.886, 0.85, 1]
# http://www.saia.com/ saia
# http://www.saia.com/ saia ltl freight
#
# ['http://www.wikidata.org/entity/Q941127', '858', 1.0, 1.0, 1]
# https://www.salesforce.com/ salesforce
# http://www.salesforce.com/ salesforce
#
# ['http://www.wikidata.org/entity/Q110287763', '846', 0.8021428571428572, 0.9607142857142857, 0.3]
#  select media llc
# http://www.wicresoft.com/ select medical
#
# ['http://www.wikidata.org/entity/Q3483455', '777', 1.0, 1.0, 1]
# http://www.sncorp.com/ sierra nevada corporation
# http://www.sncorp.com/ sierra nevada corporation
#
# ['http://www.wikidata.org/entity/Q28225929', '145', 0.773, 0.9223684210526316, 0.3]
#  source interlink
# http://www.lucasjamestalent.com/ source intelligence
#
# ['http://www.wikidata.org/entity/Q478214', '287', 0.9170909090909092, 0.890909090909091, 1]
# https://www.tesla.com/ tesla, inc.
# http://www.tesla.com/ tesla
#
# ['http://www.wikidata.org/entity/Q688825', '896', 1.0, 1.0, 1]
# https://www.traderjoes.com/ trader joe's
# http://www.traderjoes.com/ trader joe's
#
# ['http://www.wikidata.org/entity/Q795486', '49', 1.0, 1.0, 1]
# https://www.truist.com/ truist financial
# https://www.truist.com/ truist financial
#
# ['http://www.wikidata.org/entity/Q45137217', '2', 0.7686666666666667, 0.9166666666666667, 0.3]
#  takeda pharmaceuticals north america
# http://www.takeda.com/ takeda pharmaceutical
#
# ['http://www.wikidata.org/entity/Q7743510', '576', 0.7654095238095238, 0.9123809523809524, 0.3]
#  the jones group
# http://www.thejosefgroup.com/ the josef group inc.
#
# ['http://www.wikidata.org/entity/Q7764745', '620', 0.8008761904761904, 0.959047619047619, 0.3]
#  the slate group
# http://www.saleminc.com/ the salem group
#
# ['http://www.wikidata.org/entity/Q7764745', '690', 0.7759686274509804, 0.9262745098039216, 0.3]
#  the slate group
# http://www.theapptechgroup.com/ the apptech group
#
# ['http://www.wikidata.org/entity/Q7764745', '151', 0.7787999999999999, 0.9299999999999999, 0.3]
#  the slate group
# http://www.thehtgroup.com/ the ht group
#
# ['http://www.wikidata.org/entity/Q7746584', '620', 0.7642763197586726, 0.9108898944193061, 0.3]
#  the leavitt group
# http://www.saleminc.com/ the salem group
#
# ['http://www.wikidata.org/entity/Q7746584', '151', 0.7656862745098039, 0.9127450980392157, 0.3]
#  the leavitt group
# http://www.thehtgroup.com/ the ht group
#
# ['http://www.wikidata.org/entity/Q7746584', '96', 0.7642763197586726, 0.9108898944193061, 0.3]
#  the leavitt group
# http://www.thebritegroup.com/ the brite group
#
# ['http://www.wikidata.org/entity/Q864407', '5', 0.76, 1.0, 0]
# https://www.homedepot.com/ the home depot
# http://www.careers.homedepot.com/ the home depot
#
# ['http://www.wikidata.org/entity/Q7720649', '96', 0.7914666666666667, 0.9466666666666667, 0.3]
#  the burke group
# http://www.thebritegroup.com/ the brite group
#
# ['http://www.wikidata.org/entity/Q942471', '903', 0.968551724137931, 0.9586206896551724, 1]
# http://www.travelers.com/ the travelers companies
# http://www.travelers.com/ the travelers companies, inc.
#
# ['http://www.wikidata.org/entity/Q739084', '692', 0.7593333333333333, 0.6833333333333332, 1]
# https://www.usbank.com/ u.s. bancorp
# http://www.usbank.com/ u.s. bank national association
#
# ['http://www.wikidata.org/entity/Q7893878', '748', 0.7721111111111111, 0.9211988304093567, 0.3]
#  universal airlines
# http://www.univstainless.com/ universal stainless
#
# ['http://www.wikidata.org/entity/Q7895692', '130', 1.0, 1.0, 1]
# https://www.umms.org/ university of maryland medical system
# http://www.umms.org/ university of maryland medical system
#
# ['http://www.wikidata.org/entity/Q2103926', '20', 0.9292777777777778, 0.9069444444444444, 1]
# http://www.unitedhealthgroup.com/ unitedhealth group
# http://www.unitedhealthgroup.com/ unitedhealthcare
#
# ['http://www.wikidata.org/entity/Q7893927', '865', 0.7598383838383838, 0.905050505050505, 0.3]
#  universal cooperatives
# http://www.universaltek.com/ universal technologies
#
# ['http://www.wikidata.org/entity/Q7865722', '6', 0.76, 1.0, 0]
# https://www.usaa.com/ usaa
# http://www.usaajobs.com/ usaa
#
# ['http://www.wikidata.org/entity/Q780442', '779', 0.8885333333333333, 0.8533333333333333, 1]
# https://www.uber.com/ uber technology
# http://www.uber.com/ uber
#
# ['http://www.wikidata.org/entity/Q7934633', '735', 0.9609038461538462, 0.9485576923076924, 1]
# http://www.vatransformer.com/ virginia transformer corporation
# https://www.vatransformer.com/ virginia transformers corp
#
# ['http://www.wikidata.org/entity/Q2516971', '636', 1.0, 1.0, 1]
# http://www.virtusa.com/ virtusa
# http://www.virtusa.com/ virtusa
#
# ['http://www.wikidata.org/entity/Q104158381', '204', 0.76, 1.0, 0]
# https://www.vistracorp.com/ vistra
# https://www.vistra.com/ vistra
#
# ['http://www.wikidata.org/entity/Q328840', '861', 0.9155555555555556, 0.888888888888889, 1]
# https://www.visa.com/ visa inc.
# http://www.visa.com/ visa
#
# ['http://www.wikidata.org/entity/Q467752', '891', 0.76, 1.0, 0]
# http://www.verizon.com/ verizon
# http://verizon.com/jobs/ verizon
#
# ['http://www.wikidata.org/entity/Q7947769', '795', 0.832, 1.0, 0.3]
#  wcg
# http://www.wcgclinical.com/ wcg
#
# ['http://www.wikidata.org/entity/Q21016487', '196', 0.76, 1.0, 0]
# http://www.westrock.com/en-us/index.html/ westrock
# http://www.westrock.com/ westrock
#
# ['http://www.wikidata.org/entity/Q483551', '1', 0.76, 1.0, 0]
# https://www.walmart.com/ walmart
# http://careers.walmart.com/ walmart
#
# ['http://www.wikidata.org/entity/Q60764327', '912', 1.0, 1.0, 1]
# http://www.walkerdunlop.com/ walker & dunlop
# https://www.walkerdunlop.com/ walker & dunlop
#
# ['http://www.wikidata.org/entity/Q15330', '77', 0.76, 1.0, 0]
# https://waymo.com/ waymo
# http://www.waymo.com/ waymo
#
# ['http://www.wikidata.org/entity/Q2581220', '598', 0.9294285714285714, 0.9071428571428571, 1]
# http://www.williams-sonomainc.com/ williams-sonoma
# http://www.williams-sonomainc.com/ williams-sonoma-supply chain
#
# ['http://www.wikidata.org/entity/Q1367937', '224', 0.9145, 0.8875, 1]
# https://www.wolfram.com/ wolfram research
# http://www.wolfram.com/ wolfram
#
# ['http://www.wikidata.org/entity/Q50036835', '654', 0.9406829268292684, 0.9219512195121952, 1]
# https://www.worldwide.com/ worldwide clinical trials (united states)
# http://www.worldwide.com/ worldwide clinical trials
#
# ['http://www.wikidata.org/entity/Q7705659', '84', 0.8927058823529411, 0.8588235294117647, 1]
# https://xperi.com/ xperi corporation
# https://xperi.com/ xperi
#
# ['http://www.wikidata.org/entity/Q17108686', '339', 0.784, 0.9368421052631579, 0.3]
#  yardi systems
# http://www.yardi.com/ yardi systems, inc.
#
# ['http://www.wikidata.org/entity/Q95929737', '362', 1.0, 1.0, 1]
# https://www.zennioptical.com/ zenni optical
# http://www.zennioptical.com/ zenni optical
#
# ['http://www.wikidata.org/entity/Q8071921', '112', 1.0, 1.0, 1]
# http://www.zillow.com/ zillow
# https://www.zillow.com/ zillow

# %%
# deduplicate
matchPairs_wg1 = {}
# depulicate wikidata id:
for ids in matchPairs_wg:
    if ids[0] not in matchPairs_wg1:
        matchPairs_wg1[ids[0]] = []
    matchPairs_wg1[ids[0]].append(ids)
for i in matchPairs_wg1:
    if len(matchPairs_wg1[i]) > 1:
        best = max(matchPairs_wg1[i], key=lambda x: x[2])
        matchPairs_wg1[i] = best
    else:
        matchPairs_wg1[i] = matchPairs_wg1[i][0]

# depulicate glassdoor id:
matchPairs_wg2 = {}
for ids in matchPairs_wg1.values():
    if ids[1] not in matchPairs_wg2:
        matchPairs_wg2[ids[1]] = []
    matchPairs_wg2[ids[1]].append(ids)

for i in matchPairs_wg2:
    if len(matchPairs_wg2[i]) > 1:
        best = max(matchPairs_wg2[i], key=lambda x: x[2])
        matchPairs_wg2[i] = best
    else:
        matchPairs_wg2[i] = matchPairs_wg2[i][0]
matchPairs_wg_deduplicate = list(matchPairs_wg2.values())
len(matchPairs_wg_deduplicate)
# Out:
# 145

# %%
with open(dir_ + 'linkage/w_g_linkage.csv', mode='w') as file:
    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(["wikidata.id", "glassdoor.id"])
    for row in matchPairs_wg_deduplicate:
        writer.writerow((row[0], row[1]))

# %%
def findID(id1, lst1):
    for i in lst1:
        if i[0] == id1:
            return i[1]
    return None

def findID2(id1, lst1):
    for i in lst1:
        if i[1] == id1:
            return i[0]
    return None

# %%
# combine three
# glassdoor - linkedin - wikidata
matchPairs_3 = []
id_gs = [i[0] for i in matchPairs]
for id_wg in matchPairs_wg_deduplicate:
    id_w, id_g = id_wg[0], id_wg[1]
    if id_g in id_gs:
        id_l = findID(id_g, matchPairs)
        matchPairs_3.append([id_g, id_l, id_w])

id_ls = [i[1] for i in matchPairs]
id_ls2 = [i[1] for i in matchPairs_3]
for id_wl in matchPairs_wl_deduplicate:
    id_w, id_l = id_wl[0], id_wl[1]
    if id_l in id_ls and id_l not in id_ls2:
        id_g = findID2(id_l, matchPairs)
        matchPairs_3.append([id_g, id_l, id_w])

# %%
matchPairs_3
# Out:
# [['52', '1858', 'http://www.wikidata.org/entity/Q484930'],
#  ['487', '1237', 'http://www.wikidata.org/entity/Q23018218'],
#  ['592', '1756', 'http://www.wikidata.org/entity/Q219508'],
#  ['95', '1107', 'http://www.wikidata.org/entity/Q23016736'],
#  ['921', '1022', 'http://www.wikidata.org/entity/Q5272601'],
#  ['550', '1340', 'http://www.wikidata.org/entity/Q15589464'],
#  ['377', '1576', 'http://www.wikidata.org/entity/Q1538585'],
#  ['25', '2314', 'http://www.wikidata.org/entity/Q1516450'],
#  ['736', '2472', 'http://www.wikidata.org/entity/Q634815'],
#  ['102', '1673', 'http://www.wikidata.org/entity/Q6982632'],
#  ['60', '2388', 'http://www.wikidata.org/entity/Q108443888'],
#  ['5', '2434', 'http://www.wikidata.org/entity/Q864407'],
#  ['6', '2633', 'http://www.wikidata.org/entity/Q7865722'],
#  ['779', '2358', 'http://www.wikidata.org/entity/Q780442']]

# %%
with open(dir_ + 'linkage/g_l_w_linkage.csv', mode='w') as file:
    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(["glassdoor.id", "linkedin.id", "wikidata.id"])
    for row in matchPairs_3:
        writer.writerow((row[0], row[1], row[2]))
